# %%
# !pip install ipywidgets

# %%
# !pip install seaborn

# %%
# !pip install transformers

# %%
import pandas as pd
import numpy as np
import torch
from tqdm.notebook import tqdm

from transformers import BertTokenizer
from torch.utils.data import TensorDataset

from transformers import BertForSequenceClassification

from matplotlib import pyplot as plt
import seaborn as sns

from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# # Get data

# %%
from google.colab import drive
import tensorflow as tf

drive.mount('/content/drive')
# %cd drive/MyDrive/twitter_training/

# %%
df = pd.read_csv('./p_n_n_tilde_lv_clean.csv')
# df = pd.read_csv('./../../labeledTweets/p_n_n_tilde_lv_clean.csv')
df = df[['id', 'message_lv_tilde', 'label']]
df.head()
# Out:
#              id                                   message_lv_tilde  label
# 0  1.340000e+18  @pilsonenjeff @lauferlaw @donwinslows pa reize...      2
# 1  1.330000e+18  @tkdylan cilvēkiem ir aģentūra. Lins Vuds ir v...      2
# 2  1.330000e+18  @foenixaew Es nojaušu, ka WWE lika viņam iznāk...      2
# 3  1.320000e+18  Maksvels droši vien pačurās mājā pirms mūsu nā...      2
# 4  1.320000e+18  @msamson56 Esmu pārsteigts. KĀ cilvēki var atb...      2

# %%
label_dict = {'neutral': 0, 'positive': 1, 'negative': 2}
df['label'] = df.label.replace(label_dict) 
df['label'].value_counts()
# Out:
# 0    77028
# 1    51994
# 2    45622
# Name: label, dtype: int64

# %%
newLine ="\\n|\\r"
urls = '(https?:\/\/(?:www\.|(?!www))[a-zA-Z0-9][a-zA-Z0-9-]+[a-zA-Z0-9]\.[^\s]{2,}|www\.[a-zA-Z0-9][a-zA-Z0-9-]+[a-zA-Z0-9]\.[^\s]{2,}|https?:\/\/(?:www\.|(?!www))[a-zA-Z0-9]+\.[^\s]{2,}|www\.[a-zA-Z0-9]+\.[^\s]{2,})'
numbers = '\d+((\.|\-)\d+)?'
mentions = '\B\@([\w\-]+)'
hashtag = '#'
whitespaces = '\s+'
leadTrailWhitespace = '^\s+|\s+?$'

df['clean_message'] = df['message_lv_tilde']
df['clean_message'] = df['clean_message'].str.replace(newLine,' ',regex=True)
df['clean_message'] = df['clean_message'].str.replace(urls,' URL ',regex=True)
df['clean_message'] = df['clean_message'].str.replace(mentions,' MENTION ',regex=True)
df['clean_message'] = df['clean_message'].str.replace(numbers,' NMBR ',regex=True)
df['clean_message'] = df['clean_message'].str.replace(hashtag,' ',regex=True)
df['clean_message'] = df['clean_message'].str.replace(whitespaces,' ',regex=True)
df['clean_message'] = df['clean_message'].str.replace(leadTrailWhitespace,'',regex=True)

df.head()
# Out:
#              id                                   message_lv_tilde  label  \
# 0  1.340000e+18  @pilsonenjeff @lauferlaw @donwinslows pa reize...      2
# 1  1.330000e+18  @tkdylan cilvēkiem ir aģentūra. Lins Vuds ir v...      2
# 2  1.330000e+18  @foenixaew Es nojaušu, ka WWE lika viņam iznāk...      2
# 3  1.320000e+18  Maksvels droši vien pačurās mājā pirms mūsu nā...      2
# 4  1.320000e+18  @msamson56 Esmu pārsteigts. KĀ cilvēki var atb...      2
#
#                                        clean_message
# 0  MENTION MENTION MENTION pa reizei tādu nav bij...
# 1  MENTION cilvēkiem ir aģentūra. Lins Vuds ir va...
# 2  MENTION Es nojaušu, ka WWE lika viņam iznākt a...
# 3  Maksvels droši vien pačurās mājā pirms mūsu nā...
# 4  MENTION Esmu pārsteigts. KĀ cilvēki var atbals...

# %% [markdown]
# # Train, validate split

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(df.index.values, 
                                                  df.label.values, 
                                                  test_size=0.15, 
                                                  random_state=42, 
                                                  stratify=df.label.values)

# %%
df['data_type'] = ['not_set']*df.shape[0]

df.loc[X_train, 'data_type'] = 'train'
df.loc[X_val, 'data_type'] = 'val'

df.groupby(['label', 'data_type']).count()
# Out:
#                     id  message_lv_tilde  clean_message
# label data_type
# 0     train      65474             65474          65474
#       val        11554             11554          11554
# 1     train      44195             44195          44195
#       val         7799              7799           7799
# 2     train      38778             38778          38778
#       val         6844              6844           6844

# %%
df.head()
# Out:
#              id                                   message_lv_tilde  label  \
# 0  1.340000e+18  @pilsonenjeff @lauferlaw @donwinslows pa reize...      2
# 1  1.330000e+18  @tkdylan cilvēkiem ir aģentūra. Lins Vuds ir v...      2
# 2  1.330000e+18  @foenixaew Es nojaušu, ka WWE lika viņam iznāk...      2
# 3  1.320000e+18  Maksvels droši vien pačurās mājā pirms mūsu nā...      2
# 4  1.320000e+18  @msamson56 Esmu pārsteigts. KĀ cilvēki var atb...      2
#
#                                        clean_message data_type
# 0  MENTION MENTION MENTION pa reizei tādu nav bij...     train
# 1  MENTION cilvēkiem ir aģentūra. Lins Vuds ir va...     train
# 2  MENTION Es nojaušu, ka WWE lika viņam iznākt a...     train
# 3  Maksvels droši vien pačurās mājā pirms mūsu nā...     train
# 4  MENTION Esmu pārsteigts. KĀ cilvēki var atbals...       val

# %% [markdown]
# ## Balance training data

# %%
df[df.data_type=='train']['label'].value_counts()
# Out:
# 0    65474
# 1    44195
# 2    38778
# Name: label, dtype: int64

# %%
df_train = [df[df.data_type=='train'].clean_message, df[df.data_type=='train'].label]
df_train = pd.concat(df_train, axis=1, keys=["clean_message", "label"])

df_0 = df_train[df_train['label']==0]
df_1 = df_train[df_train['label']==1]
df_2 = df_train[df_train['label']==2]

df_0_downsampled = df_0.sample(df_2.shape[0], random_state=42)
df_1_downsampled = df_1.sample(df_2.shape[0], random_state=42)

df_train = pd.concat([df_0_downsampled, df_1_downsampled, df_2])

df_train['label'].value_counts()
# Out:
# 0    38778
# 1    38778
# 2    38778
# Name: label, dtype: int64

# %%
# Shuffle rows
import sklearn

df_train = sklearn.utils.shuffle(df_train, random_state=0)

df_train.head()
# Out:
#                                             clean_message  label
# 173549  Negadījums. divas labās joslas bloķētas TriSta...      0
# 13774   labākais, ko ab ir pilnībā ielenkusi tukši dzī...      2
# 86302   Piemērojot to visu šajā nākamajā nodaļā, uzspi...      1
# 77847   MENTION Es cerēju, ka jūs galu galā izdarīsiet...      1
# 14670   MENTION MENTION MENTION MENTION MENTION Jā, mē...      2

# %% [markdown]
# # Tokenizer "bert-base-multilingual-cased"

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-multilingual-cased', do_lower_case=True)

# %% [markdown]
# ## Find popular UNK tokens

# %%
unk_tokens = []
for message in df.clean_message.values:
    list_of_space_separated_pieces = message.strip().split()
    ids = [tokenizer(piece, add_special_tokens=False, max_length=1011)["input_ids"] for piece in list_of_space_separated_pieces]
    unk_indices = [i for i, encoded in enumerate(ids) if tokenizer.unk_token_id in encoded]
    unknown_strings = [piece for i, piece in enumerate(list_of_space_separated_pieces) if i in unk_indices]
    for unk_str in unknown_strings:
        unk_tokens.append(unk_str)
# Out:
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.

# %%
import collections

counter=collections.Counter(unk_tokens)
print(counter.most_common(100))

most_common_values= [word for word, word_count in counter.most_common(100)]
print(most_common_values)

# %%
most_common_values = ['️', '😂', '😭', '…', '🤣', '❤', '🏾', '🏽', '🙏', '🔥', '🏻', '✨', '🏼', '🤷', '–', '🤦', '🥺', '😩', '🥰', '🤔', '🥴', '👏', '💯', '😍', '🙄', '🇺', '🙌', '💙', '🇸', '“Es', '💀', '👀', '—', '“', '😅', '💜', '💕', '😊', '👍', '💪', '😘', '😔', '💔', '😒', '🚨', '🙃', '🏿', '🚀', '😎', '‼', '😉', '🎄', '😁', '🖤', '😌', '😢', '🎶', '🎉', '🤗', '😆', '✊', '✌', '💛', '🥳', '😤', '😳', '🌟', '🤬', '👌', '👇', '🤩', '😬', '💖', '😡', '☺', '💋', '🌹', '⠀', '🤍', '🗣', '😫', '💚', '❄', '💗', '😈', '🙂', '😞', '😂,', '”', '😷', '🇷', '🤯', '😀', '“vai', '⃣', '💰', '😭,', '😴', '😏', '🤞']

# %%
len(tokenizer)

# %%
tokenizer.add_tokens(most_common_values, special_tokens=True)
# Out:
# 100

# %%
len(tokenizer)

# %% [markdown]
# ### Find max length for tokenizer

# %%
token_lens = []
for txt in list(df.clean_message.values):
    tokens = tokenizer.encode(txt, max_length=512, truncation=True)
    token_lens.append(len(tokens))
    
sns.displot(token_lens)
plt.xlim([0, 250])
plt.xlabel('Token count')
plt.show()

# %%
max_length = 180

# %% [markdown]
# ### Encode messages

# %%
encoded_data_train = tokenizer.batch_encode_plus(
    df_train["clean_message"].values, 
    add_special_tokens=True, 
    return_attention_mask=True, 
    pad_to_max_length=True, 
    max_length=max_length, 
    return_tensors='pt'
)

encoded_data_val = tokenizer.batch_encode_plus(
    df[df.data_type=='val'].clean_message.values, 
    add_special_tokens=True, 
    return_attention_mask=True, 
    pad_to_max_length=True, 
    max_length=max_length, 
    return_tensors='pt'
)


input_ids_train = encoded_data_train['input_ids']
attention_masks_train = encoded_data_train['attention_mask']
labels_train = torch.tensor(df_train.label.values)

input_ids_val = encoded_data_val['input_ids']
attention_masks_val = encoded_data_val['attention_mask']
labels_val = torch.tensor(df[df.data_type=='val'].label.values)

dataset_train = TensorDataset(input_ids_train, attention_masks_train, labels_train)
dataset_val = TensorDataset(input_ids_val, attention_masks_val, labels_val)
# Out:
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# C:\Users\aligo\anaconda3\lib\site-packages\transformers\tokenization_utils_base.py:2251: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(

# %%
len(dataset_train), len(dataset_val)
# Out:
# (116334, 26197)

# %% [markdown]
# # Model "bert-base-multilingual-cased"

# %%
model = BertForSequenceClassification.from_pretrained("bert-base-multilingual-cased",
                                                      num_labels=3,
                                                      output_attentions=False,
                                                      output_hidden_states=False)
# Out:
# Some weights of the model checkpoint at bert-base-multilingual-cased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
model.resize_token_embeddings(len(tokenizer))
# Out:
# Embedding(119647, 768)

# %%
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler

batch_size = 3

dataloader_train = DataLoader(dataset_train, sampler=RandomSampler(dataset_train), batch_size=batch_size)
dataloader_validation = DataLoader(dataset_val, sampler=SequentialSampler(dataset_val), batch_size=batch_size)

# %%
from transformers import get_linear_schedule_with_warmup

optimizer = torch.optim.AdamW(model.parameters(), lr=1e-5, eps=1e-8)

# %%
epochs = 1

scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps=0, num_training_steps=len(dataloader_train)*epochs)

# %%
# Function to measure weighted F1

from sklearn.metrics import f1_score

def f1_score_func(preds, labels):
    preds_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()
    return f1_score(labels_flat, preds_flat, average='weighted')

# %%
import random

seed_val = 17
random.seed(seed_val)
np.random.seed(seed_val)
torch.manual_seed(seed_val)
torch.cuda.manual_seed_all(seed_val)

# device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device = torch.device('cpu')
model.to(device)
print(device)
# Out:
# cpu

# %%
# Function to evaluate model. Returns average validation loss, predictions, true values

def evaluate(dataloader_val):

    model.eval()
    
    loss_val_total = 0
    predictions, true_vals = [], []
    
    progress_bar = tqdm(dataloader_val, desc='Validating', leave=False, disable=False)
    for batch in progress_bar:
        
        batch = tuple(b.to(device) for b in batch)
        
        inputs = {'input_ids':      batch[0],
                  'attention_mask': batch[1],
                  'labels':         batch[2],
                 }

        with torch.no_grad():        
            outputs = model(**inputs)
            
        loss = outputs[0]
        logits = outputs[1]
        loss_val_total += loss.item()

        logits = logits.detach().cpu().numpy()
        label_ids = inputs['labels'].cpu().numpy()
        predictions.append(logits)
        true_vals.append(label_ids)
    
    loss_val_avg = loss_val_total/len(dataloader_val) 
    
    predictions = np.concatenate(predictions, axis=0)
    true_vals = np.concatenate(true_vals, axis=0)
            
    return loss_val_avg, predictions, true_vals

# %% [markdown]
# # Train

# %%
from tqdm import tqdm

for epoch in tqdm(range(1, epochs+1)):
    
    model.train()
    
    loss_train_total = 0

    progress_bar = tqdm(dataloader_train, desc='Epoch {:1d}'.format(epoch), leave=False, disable=False)
    for batch in progress_bar:

        model.zero_grad()
        
        batch = tuple(b.to(device) for b in batch)
        
        inputs = {'input_ids':      batch[0],
                  'attention_mask': batch[1],
                  'labels':         batch[2],
                 }       

        outputs = model(**inputs)
        
        loss = outputs[0]
        loss_train_total += loss.item()
        loss.backward()

        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)

        optimizer.step()
        scheduler.step()
        
        progress_bar.set_postfix({'training_loss': '{:.3f}'.format(loss.item()/len(batch))})
         
        
    torch.save(model.state_dict(), f'modelsUNK-pnn/finetuned_BERT_epoch_{epoch}.model')
        
    tqdm.write(f'\nEpoch {epoch}')
    
    loss_train_avg = loss_train_total/len(dataloader_train)            
    tqdm.write(f'Training loss: {loss_train_avg}')
    
    val_loss, predictions, true_vals = evaluate(dataloader_validation)
    val_f1 = f1_score_func(predictions, true_vals)
    tqdm.write(f'Validation loss: {val_loss}')
    tqdm.write(f'F1 Score (Weighted): {val_f1}')
    
    preds_flat = np.argmax(predictions, axis=1).flatten()
    
    print('Classification report:')
    print(classification_report(true_vals, preds_flat))
    print('Confusion matrix:')
    print(pd.DataFrame(confusion_matrix(true_vals, preds_flat),
            index = [['actual', 'actual', 'actual'], ['neutral', 'positive', 'negative']],
            columns = [['predicted', 'predicted', 'predicted'], ['neutral', 'positive', 'negative']]))
    print('--------------------------------------------------------------')
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 1:   0%|          | 0/38778 [00:00<?, ?it/s]
# Epoch 1:   0%|          | 0/38778 [00:00<?, ?it/s, training_loss=0.363]
# Epoch 1:   0%|          | 1/38778 [00:00<4:09:26,  2.59it/s, training_loss=0.363]
# Epoch 1:   0%|          | 1/38778 [00:00<4:09:26,  2.59it/s, training_loss=0.305]
# Epoch 1:   0%|          | 2/38778 [00:00<4:02:49,  2.66it/s, training_loss=0.305]
# Epoch 1:   0%|          | 2/38778 [00:01<4:02:49,  2.66it/s, training_loss=0.331]
# Epoch 1:   0%|          | 3/38778 [00:01<4:00:41,  2.69it/s, training_loss=0.331]
# Epoch 1:   0%|          | 3/38778 [00:01<4:00:41,  2.69it/s, training_loss=0.287]
# Epoch 1:   0%|          | 4/38778 [00:01<3:59:52,  2.69it/s, training_loss=0.287]
# Epoch 1:   0%|          | 4/38778 [00:01<3:59:52,  2.69it/s, training_loss=0.255]
# Epoch 1:   0%|          | 5/38778 [00:01<3:59:57,  2.69it/s, training_loss=0.255]
# Epoch 1:   0%|          | 5/38778 [00:02<3:59:57,  2.69it/s, training_loss=0.304]
# Epoch 1:   0%|          | 6/38778 [00:02<3:59:40,  2.70it/s, training_loss=0.304]
# Epoch 1:   0%|          | 6/38778 [00:02<3:59:40,  2.70it/s, training_loss=0.362]
# Epoch 1:   0%|          | 7/38778 [00:02<3:59:40,  2.70it/s, training_loss=0.362]
# Epoch 1:   0%|          | 7/38778 [00:02<3:59:40,  2.70it/s, training_loss=0.336]
# Epoch 1:   0%|          | 8/38778 [00:02<3:59:51,  2.69it/s, training_loss=0.336]
# Epoch 1:   0%|          | 8/38778 [00:03<3:59:51,  2.69it/s, training_loss=0.223]
# Epoch 1:   0%|          | 9/38778 [00:03<3:59:47,  2.69it/s, training_loss=0.223]
# Epoch 1:   0%|          | 9/38778 [00:03<3:59:47,  2.69it/s, training_loss=0.407]
# Epoch 1:   0%|          | 10/38778 [00:03<3:59:30,  2.70it/s, training_loss=0.407]
# Epoch 1:   0%|          | 10/38778 [00:04<3:59:30,  2.70it/s, training_loss=0.437]
# Epoch 1:   0%|          | 11/38778 [00:04<3:59:38,  2.70it/s, training_loss=0.437]
# Epoch 1:   0%|          | 11/38778 [00:04<3:59:38,  2.70it/s, training_loss=0.293]
# Epoch 1:   0%|          | 12/38778 [00:04<3:59:38,  2.70it/s, training_loss=0.293]
# Epoch 1:   0%|          | 12/38778 [00:04<3:59:38,  2.70it/s, training_loss=0.359]
# Epoch 1:   0%|          | 13/38778 [00:04<3:59:49,  2.69it/s, training_loss=0.359]
# Epoch 1:   0%|          | 13/38778 [00:05<3:59:49,  2.69it/s, training_loss=0.295]
# Epoch 1:   0%|          | 14/38778 [00:05<3:59:36,  2.70it/s, training_loss=0.295]
# Epoch 1:   0%|          | 14/38778 [00:05<3:59:36,  2.70it/s, training_loss=0.261]
# Epoch 1:   0%|          | 15/38778 [00:05<3:59:21,  2.70it/s, training_loss=0.261]
# Epoch 1:   0%|          | 15/38778 [00:05<3:59:21,  2.70it/s, training_loss=0.203]
# Epoch 1:   0%|          | 16/38778 [00:05<3:59:22,  2.70it/s, training_loss=0.203]
# Epoch 1:   0%|          | 16/38778 [00:06<3:59:22,  2.70it/s, training_loss=0.422]
# Epoch 1:   0%|          | 17/38778 [00:06<3:59:14,  2.70it/s, training_loss=0.422]
# Epoch 1:   0%|          | 17/38778 [00:06<3:59:14,  2.70it/s, training_loss=0.251]
# Epoch 1:   0%|          | 18/38778 [00:06<3:59:19,  2.70it/s, training_loss=0.251]
# Epoch 1:   0%|          | 18/38778 [00:07<3:59:19,  2.70it/s, training_loss=0.167]
# Epoch 1:   0%|          | 19/38778 [00:07<3:59:32,  2.70it/s, training_loss=0.167]
# Epoch 1:   0%|          | 19/38778 [00:07<3:59:32,  2.70it/s, training_loss=0.455]
# Epoch 1:   0%|          | 20/38778 [00:07<3:59:45,  2.69it/s, training_loss=0.455]
# Epoch 1:   0%|          | 20/38778 [00:07<3:59:45,  2.69it/s, training_loss=0.345]
# Epoch 1:   0%|          | 21/38778 [00:07<3:59:36,  2.70it/s, training_loss=0.345]
# Epoch 1:   0%|          | 21/38778 [00:08<3:59:36,  2.70it/s, training_loss=0.239]
# Epoch 1:   0%|          | 22/38778 [00:08<3:59:17,  2.70it/s, training_loss=0.239]
# Epoch 1:   0%|          | 22/38778 [00:08<3:59:17,  2.70it/s, training_loss=0.230]
# Epoch 1:   0%|          | 23/38778 [00:08<3:59:08,  2.70it/s, training_loss=0.230]
# Epoch 1:   0%|          | 23/38778 [00:08<3:59:08,  2.70it/s, training_loss=0.344]
# Epoch 1:   0%|          | 24/38778 [00:08<3:59:07,  2.70it/s, training_loss=0.344]
# Epoch 1:   0%|          | 24/38778 [00:09<3:59:07,  2.70it/s, training_loss=0.134]
# Epoch 1:   0%|          | 25/38778 [00:09<3:59:16,  2.70it/s, training_loss=0.134]
# Epoch 1:   0%|          | 25/38778 [00:09<3:59:16,  2.70it/s, training_loss=0.289]
# Epoch 1:   0%|          | 26/38778 [00:09<3:59:15,  2.70it/s, training_loss=0.289]
# Epoch 1:   0%|          | 26/38778 [00:10<3:59:15,  2.70it/s, training_loss=0.645]
# Epoch 1:   0%|          | 27/38778 [00:10<3:59:11,  2.70it/s, training_loss=0.645]
# Epoch 1:   0%|          | 27/38778 [00:10<3:59:11,  2.70it/s, training_loss=0.645]
# Epoch 1:   0%|          | 28/38778 [00:10<3:59:10,  2.70it/s, training_loss=0.645]
# Epoch 1:   0%|          | 28/38778 [00:10<3:59:10,  2.70it/s, training_loss=0.509]
# Epoch 1:   0%|          | 29/38778 [00:10<3:59:31,  2.70it/s, training_loss=0.509]
# Epoch 1:   0%|          | 29/38778 [00:11<3:59:31,  2.70it/s, training_loss=0.320]
# Epoch 1:   0%|          | 30/38778 [00:11<3:59:18,  2.70it/s, training_loss=0.320]
# Epoch 1:   0%|          | 30/38778 [00:11<3:59:18,  2.70it/s, training_loss=0.330]
# Epoch 1:   0%|          | 31/38778 [00:11<3:59:15,  2.70it/s, training_loss=0.330]
# Epoch 1:   0%|          | 31/38778 [00:11<3:59:15,  2.70it/s, training_loss=0.561]
# Epoch 1:   0%|          | 32/38778 [00:11<3:59:32,  2.70it/s, training_loss=0.561]
# Epoch 1:   0%|          | 32/38778 [00:12<3:59:32,  2.70it/s, training_loss=0.277]
# Epoch 1:   0%|          | 33/38778 [00:12<3:59:39,  2.69it/s, training_loss=0.277]
# Epoch 1:   0%|          | 33/38778 [00:12<3:59:39,  2.69it/s, training_loss=0.431]
# Epoch 1:   0%|          | 34/38778 [00:12<3:59:37,  2.69it/s, training_loss=0.431]
# Epoch 1:   0%|          | 34/38778 [00:12<3:59:37,  2.69it/s, training_loss=0.099]
# Epoch 1:   0%|          | 35/38778 [00:12<3:59:27,  2.70it/s, training_loss=0.099]
# Epoch 1:   0%|          | 35/38778 [00:13<3:59:27,  2.70it/s, training_loss=0.443]
# Epoch 1:   0%|          | 36/38778 [00:13<3:59:23,  2.70it/s, training_loss=0.443]
# Epoch 1:   0%|          | 36/38778 [00:13<3:59:23,  2.70it/s, training_loss=0.504]
# Epoch 1:   0%|          | 37/38778 [00:13<3:59:23,  2.70it/s, training_loss=0.504]
# Epoch 1:   0%|          | 37/38778 [00:14<3:59:23,  2.70it/s, training_loss=0.414]
# Epoch 1:   0%|          | 38/38778 [00:14<3:59:29,  2.70it/s, training_loss=0.414]
# Epoch 1:   0%|          | 38/38778 [00:14<3:59:29,  2.70it/s, training_loss=0.254]
# Epoch 1:   0%|          | 39/38778 [00:14<3:59:28,  2.70it/s, training_loss=0.254]
# Epoch 1:   0%|          | 39/38778 [00:14<3:59:28,  2.70it/s, training_loss=0.178]
# Epoch 1:   0%|          | 40/38778 [00:14<3:59:24,  2.70it/s, training_loss=0.178]
# Epoch 1:   0%|          | 40/38778 [00:15<3:59:24,  2.70it/s, training_loss=0.212]
# Epoch 1:   0%|          | 41/38778 [00:15<3:59:27,  2.70it/s, training_loss=0.212]
# Epoch 1:   0%|          | 41/38778 [00:15<3:59:27,  2.70it/s, training_loss=0.357]
# Epoch 1:   0%|          | 42/38778 [00:15<3:59:42,  2.69it/s, training_loss=0.357]
# Epoch 1:   0%|          | 42/38778 [00:15<3:59:42,  2.69it/s, training_loss=0.523]
# Epoch 1:   0%|          | 43/38778 [00:15<3:59:48,  2.69it/s, training_loss=0.523]
# Epoch 1:   0%|          | 43/38778 [00:16<3:59:48,  2.69it/s, training_loss=0.506]
# Epoch 1:   0%|          | 44/38778 [00:16<3:59:42,  2.69it/s, training_loss=0.506]
# Epoch 1:   0%|          | 44/38778 [00:16<3:59:42,  2.69it/s, training_loss=0.216]
# Epoch 1:   0%|          | 45/38778 [00:16<3:59:36,  2.69it/s, training_loss=0.216]
# Epoch 1:   0%|          | 45/38778 [00:17<3:59:36,  2.69it/s, training_loss=0.475]
# Epoch 1:   0%|          | 46/38778 [00:17<3:59:31,  2.70it/s, training_loss=0.475]
# Epoch 1:   0%|          | 46/38778 [00:17<3:59:31,  2.70it/s, training_loss=0.370]
# Epoch 1:   0%|          | 47/38778 [00:17<3:59:27,  2.70it/s, training_loss=0.370]
# Epoch 1:   0%|          | 47/38778 [00:17<3:59:27,  2.70it/s, training_loss=0.202]
# Epoch 1:   0%|          | 48/38778 [00:17<3:59:36,  2.69it/s, training_loss=0.202]
# Epoch 1:   0%|          | 48/38778 [00:18<3:59:36,  2.69it/s, training_loss=0.318]
# Epoch 1:   0%|          | 49/38778 [00:18<3:59:23,  2.70it/s, training_loss=0.318]
# Epoch 1:   0%|          | 49/38778 [00:18<3:59:23,  2.70it/s, training_loss=0.220]
# Epoch 1:   0%|          | 50/38778 [00:18<3:59:07,  2.70it/s, training_loss=0.220]
# Epoch 1:   0%|          | 50/38778 [00:18<3:59:07,  2.70it/s, training_loss=0.611]
# Epoch 1:   0%|          | 51/38778 [00:18<3:58:51,  2.70it/s, training_loss=0.611]
# Epoch 1:   0%|          | 51/38778 [00:19<3:58:51,  2.70it/s, training_loss=0.323]
# Epoch 1:   0%|          | 52/38778 [00:19<3:58:53,  2.70it/s, training_loss=0.323]
# Epoch 1:   0%|          | 52/38778 [00:19<3:58:53,  2.70it/s, training_loss=0.639]
# Epoch 1:   0%|          | 53/38778 [00:19<3:58:46,  2.70it/s, training_loss=0.639]
# Epoch 1:   0%|          | 53/38778 [00:20<3:58:46,  2.70it/s, training_loss=0.287]
# Epoch 1:   0%|          | 54/38778 [00:20<3:58:53,  2.70it/s, training_loss=0.287]
# Epoch 1:   0%|          | 54/38778 [00:20<3:58:53,  2.70it/s, training_loss=0.313]
# Epoch 1:   0%|          | 55/38778 [00:20<3:58:45,  2.70it/s, training_loss=0.313]
# Epoch 1:   0%|          | 55/38778 [00:20<3:58:45,  2.70it/s, training_loss=0.216]
# Epoch 1:   0%|          | 56/38778 [00:20<3:59:27,  2.70it/s, training_loss=0.216]
# Epoch 1:   0%|          | 56/38778 [00:21<3:59:27,  2.70it/s, training_loss=0.469]
# Epoch 1:   0%|          | 57/38778 [00:21<3:59:37,  2.69it/s, training_loss=0.469]
# Epoch 1:   0%|          | 57/38778 [00:21<3:59:37,  2.69it/s, training_loss=0.204]
# Epoch 1:   0%|          | 58/38778 [00:21<3:59:22,  2.70it/s, training_loss=0.204]
# Epoch 1:   0%|          | 58/38778 [00:21<3:59:22,  2.70it/s, training_loss=0.540]
# Epoch 1:   0%|          | 59/38778 [00:21<3:59:18,  2.70it/s, training_loss=0.540]
# Epoch 1:   0%|          | 59/38778 [00:22<3:59:18,  2.70it/s, training_loss=0.340]
# Epoch 1:   0%|          | 60/38778 [00:22<3:59:05,  2.70it/s, training_loss=0.340]
# Epoch 1:   0%|          | 60/38778 [00:22<3:59:05,  2.70it/s, training_loss=0.306]
# Epoch 1:   0%|          | 61/38778 [00:22<3:59:01,  2.70it/s, training_loss=0.306]
# Epoch 1:   0%|          | 61/38778 [00:22<3:59:01,  2.70it/s, training_loss=0.310]
# Epoch 1:   0%|          | 62/38778 [00:22<3:59:05,  2.70it/s, training_loss=0.310]
# Epoch 1:   0%|          | 62/38778 [00:23<3:59:05,  2.70it/s, training_loss=0.369]
# Epoch 1:   0%|          | 63/38778 [00:23<3:59:37,  2.69it/s, training_loss=0.369]
# Epoch 1:   0%|          | 63/38778 [00:23<3:59:37,  2.69it/s, training_loss=0.382]
# Epoch 1:   0%|          | 64/38778 [00:23<3:59:27,  2.69it/s, training_loss=0.382]
# Epoch 1:   0%|          | 64/38778 [00:24<3:59:27,  2.69it/s, training_loss=0.423]
# Epoch 1:   0%|          | 65/38778 [00:24<3:59:30,  2.69it/s, training_loss=0.423]
# Epoch 1:   0%|          | 65/38778 [00:24<3:59:30,  2.69it/s, training_loss=0.357]
# Epoch 1:   0%|          | 66/38778 [00:24<3:59:36,  2.69it/s, training_loss=0.357]
# Epoch 1:   0%|          | 66/38778 [00:24<3:59:36,  2.69it/s, training_loss=0.336]
# Epoch 1:   0%|          | 67/38778 [00:24<3:59:27,  2.69it/s, training_loss=0.336]
# Epoch 1:   0%|          | 67/38778 [00:25<3:59:27,  2.69it/s, training_loss=0.275]
# Epoch 1:   0%|          | 68/38778 [00:25<3:59:13,  2.70it/s, training_loss=0.275]
# Epoch 1:   0%|          | 68/38778 [00:25<3:59:13,  2.70it/s, training_loss=0.337]
# Epoch 1:   0%|          | 69/38778 [00:25<3:59:08,  2.70it/s, training_loss=0.337]
# Epoch 1:   0%|          | 69/38778 [00:25<3:59:08,  2.70it/s, training_loss=0.301]
# Epoch 1:   0%|          | 70/38778 [00:25<3:58:59,  2.70it/s, training_loss=0.301]
# Epoch 1:   0%|          | 70/38778 [00:26<3:58:59,  2.70it/s, training_loss=0.185]
# Epoch 1:   0%|          | 71/38778 [00:26<3:59:02,  2.70it/s, training_loss=0.185]
# Epoch 1:   0%|          | 71/38778 [00:26<3:59:02,  2.70it/s, training_loss=0.426]
# Epoch 1:   0%|          | 72/38778 [00:26<3:59:03,  2.70it/s, training_loss=0.426]
# Epoch 1:   0%|          | 72/38778 [00:27<3:59:03,  2.70it/s, training_loss=0.283]
# Epoch 1:   0%|          | 73/38778 [00:27<3:59:18,  2.70it/s, training_loss=0.283]
# Epoch 1:   0%|          | 73/38778 [00:27<3:59:18,  2.70it/s, training_loss=0.393]
# Epoch 1:   0%|          | 74/38778 [00:27<3:59:34,  2.69it/s, training_loss=0.393]
# Epoch 1:   0%|          | 74/38778 [00:27<3:59:34,  2.69it/s, training_loss=0.358]
# Epoch 1:   0%|          | 75/38778 [00:27<3:59:17,  2.70it/s, training_loss=0.358]
# Epoch 1:   0%|          | 75/38778 [00:28<3:59:17,  2.70it/s, training_loss=0.313]
# Epoch 1:   0%|          | 76/38778 [00:28<3:59:27,  2.69it/s, training_loss=0.313]
# Epoch 1:   0%|          | 76/38778 [00:28<3:59:27,  2.69it/s, training_loss=0.311]
# Epoch 1:   0%|          | 77/38778 [00:28<3:59:35,  2.69it/s, training_loss=0.311]
# Epoch 1:   0%|          | 77/38778 [00:28<3:59:35,  2.69it/s, training_loss=0.336]
# Epoch 1:   0%|          | 78/38778 [00:28<3:59:44,  2.69it/s, training_loss=0.336]
# Epoch 1:   0%|          | 78/38778 [00:29<3:59:44,  2.69it/s, training_loss=0.318]
# Epoch 1:   0%|          | 79/38778 [00:29<3:59:20,  2.69it/s, training_loss=0.318]
# Epoch 1:   0%|          | 79/38778 [00:29<3:59:20,  2.69it/s, training_loss=0.240]
# Epoch 1:   0%|          | 80/38778 [00:29<3:59:12,  2.70it/s, training_loss=0.240]
# Epoch 1:   0%|          | 80/38778 [00:30<3:59:12,  2.70it/s, training_loss=0.525]
# Epoch 1:   0%|          | 81/38778 [00:30<3:59:05,  2.70it/s, training_loss=0.525]
# Epoch 1:   0%|          | 81/38778 [00:30<3:59:05,  2.70it/s, training_loss=0.381]
# Epoch 1:   0%|          | 82/38778 [00:30<3:59:17,  2.70it/s, training_loss=0.381]
# Epoch 1:   0%|          | 82/38778 [00:30<3:59:17,  2.70it/s, training_loss=0.251]
# Epoch 1:   0%|          | 83/38778 [00:30<3:59:02,  2.70it/s, training_loss=0.251]
# Epoch 1:   0%|          | 83/38778 [00:31<3:59:02,  2.70it/s, training_loss=0.419]
# Epoch 1:   0%|          | 84/38778 [00:31<3:59:14,  2.70it/s, training_loss=0.419]
# Epoch 1:   0%|          | 84/38778 [00:31<3:59:14,  2.70it/s, training_loss=0.423]
# Epoch 1:   0%|          | 85/38778 [00:31<3:59:01,  2.70it/s, training_loss=0.423]
# Epoch 1:   0%|          | 85/38778 [00:31<3:59:01,  2.70it/s, training_loss=0.290]
# Epoch 1:   0%|          | 86/38778 [00:31<3:59:13,  2.70it/s, training_loss=0.290]
# Epoch 1:   0%|          | 86/38778 [00:32<3:59:13,  2.70it/s, training_loss=0.299]
# Epoch 1:   0%|          | 87/38778 [00:32<3:59:11,  2.70it/s, training_loss=0.299]
# Epoch 1:   0%|          | 87/38778 [00:32<3:59:11,  2.70it/s, training_loss=0.423]
# Epoch 1:   0%|          | 88/38778 [00:32<3:59:22,  2.69it/s, training_loss=0.423]
# Epoch 1:   0%|          | 88/38778 [00:33<3:59:22,  2.69it/s, training_loss=0.335]
# Epoch 1:   0%|          | 89/38778 [00:33<4:00:05,  2.69it/s, training_loss=0.335]
# Epoch 1:   0%|          | 89/38778 [00:33<4:00:05,  2.69it/s, training_loss=0.332]
# Epoch 1:   0%|          | 90/38778 [00:33<4:00:04,  2.69it/s, training_loss=0.332]
# Epoch 1:   0%|          | 90/38778 [00:33<4:00:04,  2.69it/s, training_loss=0.355]
# Epoch 1:   0%|          | 91/38778 [00:33<3:59:53,  2.69it/s, training_loss=0.355]
# Epoch 1:   0%|          | 91/38778 [00:34<3:59:53,  2.69it/s, training_loss=0.302]
# Epoch 1:   0%|          | 92/38778 [00:34<3:59:37,  2.69it/s, training_loss=0.302]
# Epoch 1:   0%|          | 92/38778 [00:34<3:59:37,  2.69it/s, training_loss=0.424]
# Epoch 1:   0%|          | 93/38778 [00:34<3:59:36,  2.69it/s, training_loss=0.424]
# Epoch 1:   0%|          | 93/38778 [00:34<3:59:36,  2.69it/s, training_loss=0.480]
# Epoch 1:   0%|          | 94/38778 [00:34<3:59:43,  2.69it/s, training_loss=0.480]
# Epoch 1:   0%|          | 94/38778 [00:35<3:59:43,  2.69it/s, training_loss=0.389]
# Epoch 1:   0%|          | 95/38778 [00:35<3:59:22,  2.69it/s, training_loss=0.389]
# Epoch 1:   0%|          | 95/38778 [00:35<3:59:22,  2.69it/s, training_loss=0.338]
# Epoch 1:   0%|          | 96/38778 [00:35<3:59:19,  2.69it/s, training_loss=0.338]
# Epoch 1:   0%|          | 96/38778 [00:35<3:59:19,  2.69it/s, training_loss=0.372]
# Epoch 1:   0%|          | 97/38778 [00:35<3:59:10,  2.70it/s, training_loss=0.372]
# Epoch 1:   0%|          | 97/38778 [00:36<3:59:10,  2.70it/s, training_loss=0.418]
# Epoch 1:   0%|          | 98/38778 [00:36<3:58:58,  2.70it/s, training_loss=0.418]
# Epoch 1:   0%|          | 98/38778 [00:36<3:58:58,  2.70it/s, training_loss=0.446]
# Epoch 1:   0%|          | 99/38778 [00:36<3:58:59,  2.70it/s, training_loss=0.446]
# Epoch 1:   0%|          | 99/38778 [00:37<3:58:59,  2.70it/s, training_loss=0.368]
# Epoch 1:   0%|          | 100/38778 [00:37<3:58:58,  2.70it/s, training_loss=0.368]
# Epoch 1:   0%|          | 100/38778 [00:37<3:58:58,  2.70it/s, training_loss=0.389]
# Epoch 1:   0%|          | 101/38778 [00:37<3:58:54,  2.70it/s, training_loss=0.389]
# Epoch 1:   0%|          | 101/38778 [00:37<3:58:54,  2.70it/s, training_loss=0.274]
# Epoch 1:   0%|          | 102/38778 [00:37<3:58:52,  2.70it/s, training_loss=0.274]
# Epoch 1:   0%|          | 102/38778 [00:38<3:58:52,  2.70it/s, training_loss=0.235]
# Epoch 1:   0%|          | 103/38778 [00:38<3:58:57,  2.70it/s, training_loss=0.235]
# Epoch 1:   0%|          | 103/38778 [00:38<3:58:57,  2.70it/s, training_loss=0.370]
# Epoch 1:   0%|          | 104/38778 [00:38<3:59:05,  2.70it/s, training_loss=0.370]
# Epoch 1:   0%|          | 104/38778 [00:38<3:59:05,  2.70it/s, training_loss=0.452]
# Epoch 1:   0%|          | 105/38778 [00:38<3:59:27,  2.69it/s, training_loss=0.452]
# Epoch 1:   0%|          | 105/38778 [00:39<3:59:27,  2.69it/s, training_loss=0.327]
# Epoch 1:   0%|          | 106/38778 [00:39<3:59:14,  2.69it/s, training_loss=0.327]
# Epoch 1:   0%|          | 106/38778 [00:39<3:59:14,  2.69it/s, training_loss=0.253]
# Epoch 1:   0%|          | 107/38778 [00:39<3:59:25,  2.69it/s, training_loss=0.253]
# Epoch 1:   0%|          | 107/38778 [00:40<3:59:25,  2.69it/s, training_loss=0.279]
# Epoch 1:   0%|          | 108/38778 [00:40<4:00:02,  2.68it/s, training_loss=0.279]
# Epoch 1:   0%|          | 108/38778 [00:40<4:00:02,  2.68it/s, training_loss=0.295]
# Epoch 1:   0%|          | 109/38778 [00:40<3:59:35,  2.69it/s, training_loss=0.295]
# Epoch 1:   0%|          | 109/38778 [00:40<3:59:35,  2.69it/s, training_loss=0.357]
# Epoch 1:   0%|          | 110/38778 [00:40<3:59:13,  2.69it/s, training_loss=0.357]
# Epoch 1:   0%|          | 110/38778 [00:41<3:59:13,  2.69it/s, training_loss=0.341]
# Epoch 1:   0%|          | 111/38778 [00:41<3:59:05,  2.70it/s, training_loss=0.341]
# Epoch 1:   0%|          | 111/38778 [00:41<3:59:05,  2.70it/s, training_loss=0.217]
# Epoch 1:   0%|          | 112/38778 [00:41<3:58:52,  2.70it/s, training_loss=0.217]
# Epoch 1:   0%|          | 112/38778 [00:41<3:58:52,  2.70it/s, training_loss=0.338]
# Epoch 1:   0%|          | 113/38778 [00:41<3:58:57,  2.70it/s, training_loss=0.338]
# Epoch 1:   0%|          | 113/38778 [00:42<3:58:57,  2.70it/s, training_loss=0.347]
# Epoch 1:   0%|          | 114/38778 [00:42<3:58:52,  2.70it/s, training_loss=0.347]
# Epoch 1:   0%|          | 114/38778 [00:42<3:58:52,  2.70it/s, training_loss=0.377]
# Epoch 1:   0%|          | 115/38778 [00:42<3:59:14,  2.69it/s, training_loss=0.377]
# Epoch 1:   0%|          | 115/38778 [00:43<3:59:14,  2.69it/s, training_loss=0.161]
# Epoch 1:   0%|          | 116/38778 [00:43<3:59:22,  2.69it/s, training_loss=0.161]
# Epoch 1:   0%|          | 116/38778 [00:43<3:59:22,  2.69it/s, training_loss=0.270]
# Epoch 1:   0%|          | 117/38778 [00:43<3:59:39,  2.69it/s, training_loss=0.270]
# Epoch 1:   0%|          | 117/38778 [00:43<3:59:39,  2.69it/s, training_loss=0.472]
# Epoch 1:   0%|          | 118/38778 [00:43<3:59:35,  2.69it/s, training_loss=0.472]
# Epoch 1:   0%|          | 118/38778 [00:44<3:59:35,  2.69it/s, training_loss=0.309]
# Epoch 1:   0%|          | 119/38778 [00:44<3:59:17,  2.69it/s, training_loss=0.309]
# Epoch 1:   0%|          | 119/38778 [00:44<3:59:17,  2.69it/s, training_loss=0.305]
# Epoch 1:   0%|          | 120/38778 [00:44<3:58:48,  2.70it/s, training_loss=0.305]
# Epoch 1:   0%|          | 120/38778 [00:44<3:58:48,  2.70it/s, training_loss=0.350]
# Epoch 1:   0%|          | 121/38778 [00:44<3:59:01,  2.70it/s, training_loss=0.350]
# Epoch 1:   0%|          | 121/38778 [00:45<3:59:01,  2.70it/s, training_loss=0.360]
# Epoch 1:   0%|          | 122/38778 [00:45<3:59:06,  2.69it/s, training_loss=0.360]
# Epoch 1:   0%|          | 122/38778 [00:45<3:59:06,  2.69it/s, training_loss=0.357]
# Epoch 1:   0%|          | 123/38778 [00:45<3:59:01,  2.70it/s, training_loss=0.357]
# Epoch 1:   0%|          | 123/38778 [00:46<3:59:01,  2.70it/s, training_loss=0.249]
# Epoch 1:   0%|          | 124/38778 [00:46<3:58:52,  2.70it/s, training_loss=0.249]
# Epoch 1:   0%|          | 124/38778 [00:46<3:58:52,  2.70it/s, training_loss=0.314]
# Epoch 1:   0%|          | 125/38778 [00:46<3:59:23,  2.69it/s, training_loss=0.314]
# Epoch 1:   0%|          | 125/38778 [00:46<3:59:23,  2.69it/s, training_loss=0.243]
# Epoch 1:   0%|          | 126/38778 [00:46<3:59:50,  2.69it/s, training_loss=0.243]
# Epoch 1:   0%|          | 126/38778 [00:47<3:59:50,  2.69it/s, training_loss=0.313]
# Epoch 1:   0%|          | 127/38778 [00:47<3:59:44,  2.69it/s, training_loss=0.313]
# Epoch 1:   0%|          | 127/38778 [00:47<3:59:44,  2.69it/s, training_loss=0.220]
# Epoch 1:   0%|          | 128/38778 [00:47<3:59:27,  2.69it/s, training_loss=0.220]
# Epoch 1:   0%|          | 128/38778 [00:47<3:59:27,  2.69it/s, training_loss=0.316]
# Epoch 1:   0%|          | 129/38778 [00:47<3:59:16,  2.69it/s, training_loss=0.316]
# Epoch 1:   0%|          | 129/38778 [00:48<3:59:16,  2.69it/s, training_loss=0.331]
# Epoch 1:   0%|          | 130/38778 [00:48<3:59:06,  2.69it/s, training_loss=0.331]
# Epoch 1:   0%|          | 130/38778 [00:48<3:59:06,  2.69it/s, training_loss=0.364]
# Epoch 1:   0%|          | 131/38778 [00:48<3:59:00,  2.69it/s, training_loss=0.364]
# Epoch 1:   0%|          | 131/38778 [00:48<3:59:00,  2.69it/s, training_loss=0.408]
# Epoch 1:   0%|          | 132/38778 [00:48<3:58:36,  2.70it/s, training_loss=0.408]
# Epoch 1:   0%|          | 132/38778 [00:49<3:58:36,  2.70it/s, training_loss=0.230]
# Epoch 1:   0%|          | 133/38778 [00:49<3:58:25,  2.70it/s, training_loss=0.230]
# Epoch 1:   0%|          | 133/38778 [00:49<3:58:25,  2.70it/s, training_loss=0.291]
# Epoch 1:   0%|          | 134/38778 [00:49<3:58:23,  2.70it/s, training_loss=0.291]
# Epoch 1:   0%|          | 134/38778 [00:50<3:58:23,  2.70it/s, training_loss=0.423]
# Epoch 1:   0%|          | 135/38778 [00:50<3:58:20,  2.70it/s, training_loss=0.423]
# Epoch 1:   0%|          | 135/38778 [00:50<3:58:20,  2.70it/s, training_loss=0.434]
# Epoch 1:   0%|          | 136/38778 [00:50<3:58:24,  2.70it/s, training_loss=0.434]
# Epoch 1:   0%|          | 136/38778 [00:50<3:58:24,  2.70it/s, training_loss=0.291]
# Epoch 1:   0%|          | 137/38778 [00:50<3:58:57,  2.70it/s, training_loss=0.291]
# Epoch 1:   0%|          | 137/38778 [00:51<3:58:57,  2.70it/s, training_loss=0.231]
# Epoch 1:   0%|          | 138/38778 [00:51<3:59:02,  2.69it/s, training_loss=0.231]
# Epoch 1:   0%|          | 138/38778 [00:51<3:59:02,  2.69it/s, training_loss=0.257]
# Epoch 1:   0%|          | 139/38778 [00:51<3:59:05,  2.69it/s, training_loss=0.257]
# Epoch 1:   0%|          | 139/38778 [00:51<3:59:05,  2.69it/s, training_loss=0.390]
# Epoch 1:   0%|          | 140/38778 [00:51<3:58:52,  2.70it/s, training_loss=0.390]
# Epoch 1:   0%|          | 140/38778 [00:52<3:58:52,  2.70it/s, training_loss=0.258]
# Epoch 1:   0%|          | 141/38778 [00:52<3:58:40,  2.70it/s, training_loss=0.258]
# Epoch 1:   0%|          | 141/38778 [00:52<3:58:40,  2.70it/s, training_loss=0.226]
# Epoch 1:   0%|          | 142/38778 [00:52<3:58:51,  2.70it/s, training_loss=0.226]
# Epoch 1:   0%|          | 142/38778 [00:53<3:58:51,  2.70it/s, training_loss=0.363]
# Epoch 1:   0%|          | 143/38778 [00:53<3:58:55,  2.70it/s, training_loss=0.363]
# Epoch 1:   0%|          | 143/38778 [00:53<3:58:55,  2.70it/s, training_loss=0.251]
# Epoch 1:   0%|          | 144/38778 [00:53<3:58:55,  2.69it/s, training_loss=0.251]
# Epoch 1:   0%|          | 144/38778 [00:53<3:58:55,  2.69it/s, training_loss=0.208]
# Epoch 1:   0%|          | 145/38778 [00:53<3:58:59,  2.69it/s, training_loss=0.208]
# Epoch 1:   0%|          | 145/38778 [00:54<3:58:59,  2.69it/s, training_loss=0.252]
# Epoch 1:   0%|          | 146/38778 [00:54<3:58:56,  2.69it/s, training_loss=0.252]
# Epoch 1:   0%|          | 146/38778 [00:54<3:58:56,  2.69it/s, training_loss=0.444]
# Epoch 1:   0%|          | 147/38778 [00:54<3:58:50,  2.70it/s, training_loss=0.444]
# Epoch 1:   0%|          | 147/38778 [00:54<3:58:50,  2.70it/s, training_loss=0.302]
# Epoch 1:   0%|          | 148/38778 [00:54<3:59:00,  2.69it/s, training_loss=0.302]
# Epoch 1:   0%|          | 148/38778 [00:55<3:59:00,  2.69it/s, training_loss=0.205]
# Epoch 1:   0%|          | 149/38778 [00:55<3:59:07,  2.69it/s, training_loss=0.205]
# Epoch 1:   0%|          | 149/38778 [00:55<3:59:07,  2.69it/s, training_loss=0.262]
# Epoch 1:   0%|          | 150/38778 [00:55<3:59:09,  2.69it/s, training_loss=0.262]
# Epoch 1:   0%|          | 150/38778 [00:56<3:59:09,  2.69it/s, training_loss=0.585]
# Epoch 1:   0%|          | 151/38778 [00:56<3:58:55,  2.69it/s, training_loss=0.585]
# Epoch 1:   0%|          | 151/38778 [00:56<3:58:55,  2.69it/s, training_loss=0.486]
# Epoch 1:   0%|          | 152/38778 [00:56<3:58:53,  2.69it/s, training_loss=0.486]
# Epoch 1:   0%|          | 152/38778 [00:56<3:58:53,  2.69it/s, training_loss=0.350]
# Epoch 1:   0%|          | 153/38778 [00:56<3:58:56,  2.69it/s, training_loss=0.350]
# Epoch 1:   0%|          | 153/38778 [00:57<3:58:56,  2.69it/s, training_loss=0.553]
# Epoch 1:   0%|          | 154/38778 [00:57<3:59:08,  2.69it/s, training_loss=0.553]
# Epoch 1:   0%|          | 154/38778 [00:57<3:59:08,  2.69it/s, training_loss=0.215]
# Epoch 1:   0%|          | 155/38778 [00:57<3:59:02,  2.69it/s, training_loss=0.215]
# Epoch 1:   0%|          | 155/38778 [00:57<3:59:02,  2.69it/s, training_loss=0.331]
# Epoch 1:   0%|          | 156/38778 [00:57<3:59:20,  2.69it/s, training_loss=0.331]
# Epoch 1:   0%|          | 156/38778 [00:58<3:59:20,  2.69it/s, training_loss=0.186]
# Epoch 1:   0%|          | 157/38778 [00:58<3:58:54,  2.69it/s, training_loss=0.186]
# Epoch 1:   0%|          | 157/38778 [00:58<3:58:54,  2.69it/s, training_loss=0.385]
# Epoch 1:   0%|          | 158/38778 [00:58<3:58:52,  2.69it/s, training_loss=0.385]
# Epoch 1:   0%|          | 158/38778 [00:58<3:58:52,  2.69it/s, training_loss=0.231]
# Epoch 1:   0%|          | 159/38778 [00:58<3:58:52,  2.69it/s, training_loss=0.231]
# Epoch 1:   0%|          | 159/38778 [00:59<3:58:52,  2.69it/s, training_loss=0.451]
# Epoch 1:   0%|          | 160/38778 [00:59<3:58:44,  2.70it/s, training_loss=0.451]
# Epoch 1:   0%|          | 160/38778 [00:59<3:58:44,  2.70it/s, training_loss=0.247]
# Epoch 1:   0%|          | 161/38778 [00:59<3:58:24,  2.70it/s, training_loss=0.247]
# Epoch 1:   0%|          | 161/38778 [01:00<3:58:24,  2.70it/s, training_loss=0.479]
# Epoch 1:   0%|          | 162/38778 [01:00<3:58:34,  2.70it/s, training_loss=0.479]
# Epoch 1:   0%|          | 162/38778 [01:00<3:58:34,  2.70it/s, training_loss=0.655]
# Epoch 1:   0%|          | 163/38778 [01:00<3:58:34,  2.70it/s, training_loss=0.655]
# Epoch 1:   0%|          | 163/38778 [01:00<3:58:34,  2.70it/s, training_loss=0.522]
# Epoch 1:   0%|          | 164/38778 [01:00<3:58:38,  2.70it/s, training_loss=0.522]
# Epoch 1:   0%|          | 164/38778 [01:01<3:58:38,  2.70it/s, training_loss=0.185]
# Epoch 1:   0%|          | 165/38778 [01:01<3:58:54,  2.69it/s, training_loss=0.185]
# Epoch 1:   0%|          | 165/38778 [01:01<3:58:54,  2.69it/s, training_loss=0.365]
# Epoch 1:   0%|          | 166/38778 [01:01<3:59:33,  2.69it/s, training_loss=0.365]
# Epoch 1:   0%|          | 166/38778 [01:01<3:59:33,  2.69it/s, training_loss=0.243]
# Epoch 1:   0%|          | 167/38778 [01:01<3:59:34,  2.69it/s, training_loss=0.243]
# Epoch 1:   0%|          | 167/38778 [01:02<3:59:34,  2.69it/s, training_loss=0.275]
# Epoch 1:   0%|          | 168/38778 [01:02<3:59:26,  2.69it/s, training_loss=0.275]
# Epoch 1:   0%|          | 168/38778 [01:02<3:59:26,  2.69it/s, training_loss=0.357]
# Epoch 1:   0%|          | 169/38778 [01:02<3:59:02,  2.69it/s, training_loss=0.357]
# Epoch 1:   0%|          | 169/38778 [01:03<3:59:02,  2.69it/s, training_loss=0.355]
# Epoch 1:   0%|          | 170/38778 [01:03<3:58:55,  2.69it/s, training_loss=0.355]
# Epoch 1:   0%|          | 170/38778 [01:03<3:58:55,  2.69it/s, training_loss=0.325]
# Epoch 1:   0%|          | 171/38778 [01:03<3:58:57,  2.69it/s, training_loss=0.325]
# Epoch 1:   0%|          | 171/38778 [01:03<3:58:57,  2.69it/s, training_loss=0.221]
# Epoch 1:   0%|          | 172/38778 [01:03<3:59:03,  2.69it/s, training_loss=0.221]
# Epoch 1:   0%|          | 172/38778 [01:04<3:59:03,  2.69it/s, training_loss=0.456]
# Epoch 1:   0%|          | 173/38778 [01:04<3:59:05,  2.69it/s, training_loss=0.456]
# Epoch 1:   0%|          | 173/38778 [01:04<3:59:05,  2.69it/s, training_loss=0.382]
# Epoch 1:   0%|          | 174/38778 [01:04<3:59:01,  2.69it/s, training_loss=0.382]
# Epoch 1:   0%|          | 174/38778 [01:04<3:59:01,  2.69it/s, training_loss=0.557]
# Epoch 1:   0%|          | 175/38778 [01:04<3:58:46,  2.69it/s, training_loss=0.557]
# Epoch 1:   0%|          | 175/38778 [01:05<3:58:46,  2.69it/s, training_loss=0.416]
# Epoch 1:   0%|          | 176/38778 [01:05<3:58:46,  2.69it/s, training_loss=0.416]
# Epoch 1:   0%|          | 176/38778 [01:05<3:58:46,  2.69it/s, training_loss=0.391]
# Epoch 1:   0%|          | 177/38778 [01:05<3:58:44,  2.69it/s, training_loss=0.391]
# Epoch 1:   0%|          | 177/38778 [01:06<3:58:44,  2.69it/s, training_loss=0.532]
# Epoch 1:   0%|          | 178/38778 [01:06<3:58:56,  2.69it/s, training_loss=0.532]
# Epoch 1:   0%|          | 178/38778 [01:06<3:58:56,  2.69it/s, training_loss=0.245]
# Epoch 1:   0%|          | 179/38778 [01:06<3:59:01,  2.69it/s, training_loss=0.245]
# Epoch 1:   0%|          | 179/38778 [01:06<3:59:01,  2.69it/s, training_loss=0.316]
# Epoch 1:   0%|          | 180/38778 [01:06<3:58:50,  2.69it/s, training_loss=0.316]
# Epoch 1:   0%|          | 180/38778 [01:07<3:58:50,  2.69it/s, training_loss=0.324]
# Epoch 1:   0%|          | 181/38778 [01:07<3:58:45,  2.69it/s, training_loss=0.324]
# Epoch 1:   0%|          | 181/38778 [01:07<3:58:45,  2.69it/s, training_loss=0.310]
# Epoch 1:   0%|          | 182/38778 [01:07<3:58:35,  2.70it/s, training_loss=0.310]
# Epoch 1:   0%|          | 182/38778 [01:07<3:58:35,  2.70it/s, training_loss=0.321]
# Epoch 1:   0%|          | 183/38778 [01:07<3:58:39,  2.70it/s, training_loss=0.321]
# Epoch 1:   0%|          | 183/38778 [01:08<3:58:39,  2.70it/s, training_loss=0.439]
# Epoch 1:   0%|          | 184/38778 [01:08<3:58:31,  2.70it/s, training_loss=0.439]
# Epoch 1:   0%|          | 184/38778 [01:08<3:58:31,  2.70it/s, training_loss=0.303]
# Epoch 1:   0%|          | 185/38778 [01:08<3:58:44,  2.69it/s, training_loss=0.303]
# Epoch 1:   0%|          | 185/38778 [01:09<3:58:44,  2.69it/s, training_loss=0.466]
# Epoch 1:   0%|          | 186/38778 [01:09<3:58:43,  2.69it/s, training_loss=0.466]
# Epoch 1:   0%|          | 186/38778 [01:09<3:58:43,  2.69it/s, training_loss=0.225]
# Epoch 1:   0%|          | 187/38778 [01:09<3:58:44,  2.69it/s, training_loss=0.225]
# Epoch 1:   0%|          | 187/38778 [01:09<3:58:44,  2.69it/s, training_loss=0.479]
# Epoch 1:   0%|          | 188/38778 [01:09<3:58:46,  2.69it/s, training_loss=0.479]
# Epoch 1:   0%|          | 188/38778 [01:10<3:58:46,  2.69it/s, training_loss=0.345]
# Epoch 1:   0%|          | 189/38778 [01:10<3:59:08,  2.69it/s, training_loss=0.345]
# Epoch 1:   0%|          | 189/38778 [01:10<3:59:08,  2.69it/s, training_loss=0.282]
# Epoch 1:   0%|          | 190/38778 [01:10<3:59:16,  2.69it/s, training_loss=0.282]
# Epoch 1:   0%|          | 190/38778 [01:10<3:59:16,  2.69it/s, training_loss=0.551]
# Epoch 1:   0%|          | 191/38778 [01:10<3:59:24,  2.69it/s, training_loss=0.551]
# Epoch 1:   0%|          | 191/38778 [01:11<3:59:24,  2.69it/s, training_loss=0.234]
# Epoch 1:   0%|          | 192/38778 [01:11<3:59:13,  2.69it/s, training_loss=0.234]
# Epoch 1:   0%|          | 192/38778 [01:11<3:59:13,  2.69it/s, training_loss=0.317]
# Epoch 1:   0%|          | 193/38778 [01:11<3:59:42,  2.68it/s, training_loss=0.317]
# Epoch 1:   0%|          | 193/38778 [01:11<3:59:42,  2.68it/s, training_loss=0.320]
# Epoch 1:   1%|          | 194/38778 [01:12<3:59:31,  2.68it/s, training_loss=0.320]
# Epoch 1:   1%|          | 194/38778 [01:12<3:59:31,  2.68it/s, training_loss=0.679]
# Epoch 1:   1%|          | 195/38778 [01:12<3:59:15,  2.69it/s, training_loss=0.679]
# Epoch 1:   1%|          | 195/38778 [01:12<3:59:15,  2.69it/s, training_loss=0.369]
# Epoch 1:   1%|          | 196/38778 [01:12<3:59:02,  2.69it/s, training_loss=0.369]
# Epoch 1:   1%|          | 196/38778 [01:13<3:59:02,  2.69it/s, training_loss=0.530]
# Epoch 1:   1%|          | 197/38778 [01:13<3:59:02,  2.69it/s, training_loss=0.530]
# Epoch 1:   1%|          | 197/38778 [01:13<3:59:02,  2.69it/s, training_loss=0.228]
# Epoch 1:   1%|          | 198/38778 [01:13<3:59:03,  2.69it/s, training_loss=0.228]
# Epoch 1:   1%|          | 198/38778 [01:13<3:59:03,  2.69it/s, training_loss=0.351]
# Epoch 1:   1%|          | 199/38778 [01:13<3:58:58,  2.69it/s, training_loss=0.351]
# Epoch 1:   1%|          | 199/38778 [01:14<3:58:58,  2.69it/s, training_loss=0.338]
# Epoch 1:   1%|          | 200/38778 [01:14<3:58:45,  2.69it/s, training_loss=0.338]
# Epoch 1:   1%|          | 200/38778 [01:14<3:58:45,  2.69it/s, training_loss=0.285]
# Epoch 1:   1%|          | 201/38778 [01:14<3:58:37,  2.69it/s, training_loss=0.285]
# Epoch 1:   1%|          | 201/38778 [01:14<3:58:37,  2.69it/s, training_loss=0.269]
# Epoch 1:   1%|          | 202/38778 [01:14<3:58:36,  2.69it/s, training_loss=0.269]
# Epoch 1:   1%|          | 202/38778 [01:15<3:58:36,  2.69it/s, training_loss=0.233]
# Epoch 1:   1%|          | 203/38778 [01:15<3:58:40,  2.69it/s, training_loss=0.233]
# Epoch 1:   1%|          | 203/38778 [01:15<3:58:40,  2.69it/s, training_loss=0.342]
# Epoch 1:   1%|          | 204/38778 [01:15<3:59:01,  2.69it/s, training_loss=0.342]
# Epoch 1:   1%|          | 204/38778 [01:16<3:59:01,  2.69it/s, training_loss=0.286]
# Epoch 1:   1%|          | 205/38778 [01:16<3:58:50,  2.69it/s, training_loss=0.286]
# Epoch 1:   1%|          | 205/38778 [01:16<3:58:50,  2.69it/s, training_loss=0.346]
# Epoch 1:   1%|          | 206/38778 [01:16<3:59:00,  2.69it/s, training_loss=0.346]
# Epoch 1:   1%|          | 206/38778 [01:16<3:59:00,  2.69it/s, training_loss=0.403]
# Epoch 1:   1%|          | 207/38778 [01:16<3:59:00,  2.69it/s, training_loss=0.403]
# Epoch 1:   1%|          | 207/38778 [01:17<3:59:00,  2.69it/s, training_loss=0.263]
# Epoch 1:   1%|          | 208/38778 [01:17<3:59:09,  2.69it/s, training_loss=0.263]
# Epoch 1:   1%|          | 208/38778 [01:17<3:59:09,  2.69it/s, training_loss=0.207]
# Epoch 1:   1%|          | 209/38778 [01:17<3:59:09,  2.69it/s, training_loss=0.207]
# Epoch 1:   1%|          | 209/38778 [01:17<3:59:09,  2.69it/s, training_loss=0.244]
# Epoch 1:   1%|          | 210/38778 [01:17<3:58:50,  2.69it/s, training_loss=0.244]
# Epoch 1:   1%|          | 210/38778 [01:18<3:58:50,  2.69it/s, training_loss=0.185]
# Epoch 1:   1%|          | 211/38778 [01:18<3:58:34,  2.69it/s, training_loss=0.185]
# Epoch 1:   1%|          | 211/38778 [01:18<3:58:34,  2.69it/s, training_loss=0.309]
# Epoch 1:   1%|          | 212/38778 [01:18<3:58:39,  2.69it/s, training_loss=0.309]
# Epoch 1:   1%|          | 212/38778 [01:19<3:58:39,  2.69it/s, training_loss=0.300]
# Epoch 1:   1%|          | 213/38778 [01:19<3:58:21,  2.70it/s, training_loss=0.300]
# Epoch 1:   1%|          | 213/38778 [01:19<3:58:21,  2.70it/s, training_loss=0.462]
# Epoch 1:   1%|          | 214/38778 [01:19<3:58:14,  2.70it/s, training_loss=0.462]
# Epoch 1:   1%|          | 214/38778 [01:19<3:58:14,  2.70it/s, training_loss=0.343]
# Epoch 1:   1%|          | 215/38778 [01:19<3:58:32,  2.69it/s, training_loss=0.343]
# Epoch 1:   1%|          | 215/38778 [01:20<3:58:32,  2.69it/s, training_loss=0.401]
# Epoch 1:   1%|          | 216/38778 [01:20<3:58:38,  2.69it/s, training_loss=0.401]
# Epoch 1:   1%|          | 216/38778 [01:20<3:58:38,  2.69it/s, training_loss=0.220]
# Epoch 1:   1%|          | 217/38778 [01:20<3:59:06,  2.69it/s, training_loss=0.220]
# Epoch 1:   1%|          | 217/38778 [01:20<3:59:06,  2.69it/s, training_loss=0.489]
# Epoch 1:   1%|          | 218/38778 [01:20<3:59:12,  2.69it/s, training_loss=0.489]
# Epoch 1:   1%|          | 218/38778 [01:21<3:59:12,  2.69it/s, training_loss=0.480]
# Epoch 1:   1%|          | 219/38778 [01:21<3:59:05,  2.69it/s, training_loss=0.480]
# Epoch 1:   1%|          | 219/38778 [01:21<3:59:05,  2.69it/s, training_loss=0.385]
# Epoch 1:   1%|          | 220/38778 [01:21<3:59:10,  2.69it/s, training_loss=0.385]
# Epoch 1:   1%|          | 220/38778 [01:22<3:59:10,  2.69it/s, training_loss=0.250]
# Epoch 1:   1%|          | 221/38778 [01:22<3:58:59,  2.69it/s, training_loss=0.250]
# Epoch 1:   1%|          | 221/38778 [01:22<3:58:59,  2.69it/s, training_loss=0.388]
# Epoch 1:   1%|          | 222/38778 [01:22<3:58:53,  2.69it/s, training_loss=0.388]
# Epoch 1:   1%|          | 222/38778 [01:22<3:58:53,  2.69it/s, training_loss=0.299]
# Epoch 1:   1%|          | 223/38778 [01:22<3:58:46,  2.69it/s, training_loss=0.299]
# Epoch 1:   1%|          | 223/38778 [01:23<3:58:46,  2.69it/s, training_loss=0.253]
# Epoch 1:   1%|          | 224/38778 [01:23<3:58:57,  2.69it/s, training_loss=0.253]
# Epoch 1:   1%|          | 224/38778 [01:23<3:58:57,  2.69it/s, training_loss=0.284]
# Epoch 1:   1%|          | 225/38778 [01:23<3:58:41,  2.69it/s, training_loss=0.284]
# Epoch 1:   1%|          | 225/38778 [01:23<3:58:41,  2.69it/s, training_loss=0.197]
# Epoch 1:   1%|          | 226/38778 [01:23<3:58:23,  2.70it/s, training_loss=0.197]
# Epoch 1:   1%|          | 226/38778 [01:24<3:58:23,  2.70it/s, training_loss=0.209]
# Epoch 1:   1%|          | 227/38778 [01:24<3:58:15,  2.70it/s, training_loss=0.209]
# Epoch 1:   1%|          | 227/38778 [01:24<3:58:15,  2.70it/s, training_loss=0.276]
# Epoch 1:   1%|          | 228/38778 [01:24<3:58:20,  2.70it/s, training_loss=0.276]
# Epoch 1:   1%|          | 228/38778 [01:24<3:58:20,  2.70it/s, training_loss=0.437]
# Epoch 1:   1%|          | 229/38778 [01:25<3:58:16,  2.70it/s, training_loss=0.437]
# Epoch 1:   1%|          | 229/38778 [01:25<3:58:16,  2.70it/s, training_loss=0.341]
# Epoch 1:   1%|          | 230/38778 [01:25<3:58:35,  2.69it/s, training_loss=0.341]
# Epoch 1:   1%|          | 230/38778 [01:25<3:58:35,  2.69it/s, training_loss=0.369]
# Epoch 1:   1%|          | 231/38778 [01:25<3:58:39,  2.69it/s, training_loss=0.369]
# Epoch 1:   1%|          | 231/38778 [01:26<3:58:39,  2.69it/s, training_loss=0.217]
# Epoch 1:   1%|          | 232/38778 [01:26<3:58:25,  2.69it/s, training_loss=0.217]
# Epoch 1:   1%|          | 232/38778 [01:26<3:58:25,  2.69it/s, training_loss=0.440]
# Epoch 1:   1%|          | 233/38778 [01:26<3:58:18,  2.70it/s, training_loss=0.440]
# Epoch 1:   1%|          | 233/38778 [01:26<3:58:18,  2.70it/s, training_loss=0.367]
# Epoch 1:   1%|          | 234/38778 [01:26<3:58:14,  2.70it/s, training_loss=0.367]
# Epoch 1:   1%|          | 234/38778 [01:27<3:58:14,  2.70it/s, training_loss=0.343]
# Epoch 1:   1%|          | 235/38778 [01:27<3:58:02,  2.70it/s, training_loss=0.343]
# Epoch 1:   1%|          | 235/38778 [01:27<3:58:02,  2.70it/s, training_loss=0.540]
# Epoch 1:   1%|          | 236/38778 [01:27<3:58:19,  2.70it/s, training_loss=0.540]
# Epoch 1:   1%|          | 236/38778 [01:27<3:58:19,  2.70it/s, training_loss=0.290]
# Epoch 1:   1%|          | 237/38778 [01:27<3:58:19,  2.70it/s, training_loss=0.290]
# Epoch 1:   1%|          | 237/38778 [01:28<3:58:19,  2.70it/s, training_loss=0.346]
# Epoch 1:   1%|          | 238/38778 [01:28<3:58:27,  2.69it/s, training_loss=0.346]
# Epoch 1:   1%|          | 238/38778 [01:28<3:58:27,  2.69it/s, training_loss=0.260]
# Epoch 1:   1%|          | 239/38778 [01:28<3:58:10,  2.70it/s, training_loss=0.260]
# Epoch 1:   1%|          | 239/38778 [01:29<3:58:10,  2.70it/s, training_loss=0.303]
# Epoch 1:   1%|          | 240/38778 [01:29<3:58:06,  2.70it/s, training_loss=0.303]
# Epoch 1:   1%|          | 240/38778 [01:29<3:58:06,  2.70it/s, training_loss=0.414]
# Epoch 1:   1%|          | 241/38778 [01:29<3:58:12,  2.70it/s, training_loss=0.414]
# Epoch 1:   1%|          | 241/38778 [01:29<3:58:12,  2.70it/s, training_loss=0.257]
# Epoch 1:   1%|          | 242/38778 [01:29<3:58:15,  2.70it/s, training_loss=0.257]
# Epoch 1:   1%|          | 242/38778 [01:30<3:58:15,  2.70it/s, training_loss=0.305]
# Epoch 1:   1%|          | 243/38778 [01:30<3:58:44,  2.69it/s, training_loss=0.305]
# Epoch 1:   1%|          | 243/38778 [01:30<3:58:44,  2.69it/s, training_loss=0.242]
# Epoch 1:   1%|          | 244/38778 [01:30<3:58:53,  2.69it/s, training_loss=0.242]
# Epoch 1:   1%|          | 244/38778 [01:30<3:58:53,  2.69it/s, training_loss=0.421]
# Epoch 1:   1%|          | 245/38778 [01:30<3:59:13,  2.68it/s, training_loss=0.421]
# Epoch 1:   1%|          | 245/38778 [01:31<3:59:13,  2.68it/s, training_loss=0.409]
# Epoch 1:   1%|          | 246/38778 [01:31<3:59:24,  2.68it/s, training_loss=0.409]
# Epoch 1:   1%|          | 246/38778 [01:31<3:59:24,  2.68it/s, training_loss=0.272]
# Epoch 1:   1%|          | 247/38778 [01:31<3:58:54,  2.69it/s, training_loss=0.272]
# Epoch 1:   1%|          | 247/38778 [01:32<3:58:54,  2.69it/s, training_loss=0.457]
# Epoch 1:   1%|          | 248/38778 [01:32<3:58:56,  2.69it/s, training_loss=0.457]
# Epoch 1:   1%|          | 248/38778 [01:32<3:58:56,  2.69it/s, training_loss=0.282]
# Epoch 1:   1%|          | 249/38778 [01:32<3:59:21,  2.68it/s, training_loss=0.282]
# Epoch 1:   1%|          | 249/38778 [01:32<3:59:21,  2.68it/s, training_loss=0.380]
# Epoch 1:   1%|          | 250/38778 [01:32<3:58:51,  2.69it/s, training_loss=0.380]
# Epoch 1:   1%|          | 250/38778 [01:33<3:58:51,  2.69it/s, training_loss=0.266]
# Epoch 1:   1%|          | 251/38778 [01:33<3:58:48,  2.69it/s, training_loss=0.266]
# Epoch 1:   1%|          | 251/38778 [01:33<3:58:48,  2.69it/s, training_loss=0.283]
# Epoch 1:   1%|          | 252/38778 [01:33<3:58:52,  2.69it/s, training_loss=0.283]
# Epoch 1:   1%|          | 252/38778 [01:33<3:58:52,  2.69it/s, training_loss=0.443]
# Epoch 1:   1%|          | 253/38778 [01:33<3:58:38,  2.69it/s, training_loss=0.443]
# Epoch 1:   1%|          | 253/38778 [01:34<3:58:38,  2.69it/s, training_loss=0.318]
# Epoch 1:   1%|          | 254/38778 [01:34<3:58:18,  2.69it/s, training_loss=0.318]
# Epoch 1:   1%|          | 254/38778 [01:34<3:58:18,  2.69it/s, training_loss=0.396]
# Epoch 1:   1%|          | 255/38778 [01:34<3:58:02,  2.70it/s, training_loss=0.396]
# Epoch 1:   1%|          | 255/38778 [01:35<3:58:02,  2.70it/s, training_loss=0.342]
# Epoch 1:   1%|          | 256/38778 [01:35<3:57:56,  2.70it/s, training_loss=0.342]
# Epoch 1:   1%|          | 256/38778 [01:35<3:57:56,  2.70it/s, training_loss=0.444]
# Epoch 1:   1%|          | 257/38778 [01:35<3:57:47,  2.70it/s, training_loss=0.444]
# Epoch 1:   1%|          | 257/38778 [01:35<3:57:47,  2.70it/s, training_loss=0.480]
# Epoch 1:   1%|          | 258/38778 [01:35<3:57:47,  2.70it/s, training_loss=0.480]
# Epoch 1:   1%|          | 258/38778 [01:36<3:57:47,  2.70it/s, training_loss=0.321]
# Epoch 1:   1%|          | 259/38778 [01:36<3:57:52,  2.70it/s, training_loss=0.321]
# Epoch 1:   1%|          | 259/38778 [01:36<3:57:52,  2.70it/s, training_loss=0.444]
# Epoch 1:   1%|          | 260/38778 [01:36<3:58:11,  2.70it/s, training_loss=0.444]
# Epoch 1:   1%|          | 260/38778 [01:36<3:58:11,  2.70it/s, training_loss=0.551]
# Epoch 1:   1%|          | 261/38778 [01:36<3:57:56,  2.70it/s, training_loss=0.551]
# Epoch 1:   1%|          | 261/38778 [01:37<3:57:56,  2.70it/s, training_loss=0.235]
# Epoch 1:   1%|          | 262/38778 [01:37<3:58:04,  2.70it/s, training_loss=0.235]
# Epoch 1:   1%|          | 262/38778 [01:37<3:58:04,  2.70it/s, training_loss=0.327]
# Epoch 1:   1%|          | 263/38778 [01:37<3:57:45,  2.70it/s, training_loss=0.327]
# Epoch 1:   1%|          | 263/38778 [01:37<3:57:45,  2.70it/s, training_loss=0.402]
# Epoch 1:   1%|          | 264/38778 [01:37<3:57:48,  2.70it/s, training_loss=0.402]
# Epoch 1:   1%|          | 264/38778 [01:38<3:57:48,  2.70it/s, training_loss=0.260]
# Epoch 1:   1%|          | 265/38778 [01:38<3:57:27,  2.70it/s, training_loss=0.260]
# Epoch 1:   1%|          | 265/38778 [01:38<3:57:27,  2.70it/s, training_loss=0.193]
# Epoch 1:   1%|          | 266/38778 [01:38<3:57:41,  2.70it/s, training_loss=0.193]
# Epoch 1:   1%|          | 266/38778 [01:39<3:57:41,  2.70it/s, training_loss=0.255]
# Epoch 1:   1%|          | 267/38778 [01:39<3:57:23,  2.70it/s, training_loss=0.255]
# Epoch 1:   1%|          | 267/38778 [01:39<3:57:23,  2.70it/s, training_loss=0.183]
# Epoch 1:   1%|          | 268/38778 [01:39<3:57:34,  2.70it/s, training_loss=0.183]
# Epoch 1:   1%|          | 268/38778 [01:39<3:57:34,  2.70it/s, training_loss=0.196]
# Epoch 1:   1%|          | 269/38778 [01:39<3:57:33,  2.70it/s, training_loss=0.196]
# Epoch 1:   1%|          | 269/38778 [01:40<3:57:33,  2.70it/s, training_loss=0.264]
# Epoch 1:   1%|          | 270/38778 [01:40<3:57:24,  2.70it/s, training_loss=0.264]
# Epoch 1:   1%|          | 270/38778 [01:40<3:57:24,  2.70it/s, training_loss=0.155]
# Epoch 1:   1%|          | 271/38778 [01:40<3:58:04,  2.70it/s, training_loss=0.155]
# Epoch 1:   1%|          | 271/38778 [01:40<3:58:04,  2.70it/s, training_loss=0.391]
# Epoch 1:   1%|          | 272/38778 [01:40<3:58:13,  2.69it/s, training_loss=0.391]
# Epoch 1:   1%|          | 272/38778 [01:41<3:58:13,  2.69it/s, training_loss=0.316]
# Epoch 1:   1%|          | 273/38778 [01:41<3:58:12,  2.69it/s, training_loss=0.316]
# Epoch 1:   1%|          | 273/38778 [01:41<3:58:12,  2.69it/s, training_loss=0.633]
# Epoch 1:   1%|          | 274/38778 [01:41<3:57:59,  2.70it/s, training_loss=0.633]
# Epoch 1:   1%|          | 274/38778 [01:42<3:57:59,  2.70it/s, training_loss=0.557]
# Epoch 1:   1%|          | 275/38778 [01:42<3:58:00,  2.70it/s, training_loss=0.557]
# Epoch 1:   1%|          | 275/38778 [01:42<3:58:00,  2.70it/s, training_loss=0.416]
# Epoch 1:   1%|          | 276/38778 [01:42<3:57:51,  2.70it/s, training_loss=0.416]
# Epoch 1:   1%|          | 276/38778 [01:42<3:57:51,  2.70it/s, training_loss=0.352]
# Epoch 1:   1%|          | 277/38778 [01:42<3:57:45,  2.70it/s, training_loss=0.352]
# Epoch 1:   1%|          | 277/38778 [01:43<3:57:45,  2.70it/s, training_loss=0.337]
# Epoch 1:   1%|          | 278/38778 [01:43<3:58:02,  2.70it/s, training_loss=0.337]
# Epoch 1:   1%|          | 278/38778 [01:43<3:58:02,  2.70it/s, training_loss=0.490]
# Epoch 1:   1%|          | 279/38778 [01:43<3:58:03,  2.70it/s, training_loss=0.490]
# Epoch 1:   1%|          | 279/38778 [01:43<3:58:03,  2.70it/s, training_loss=0.585]
# Epoch 1:   1%|          | 280/38778 [01:43<3:57:51,  2.70it/s, training_loss=0.585]
# Epoch 1:   1%|          | 280/38778 [01:44<3:57:51,  2.70it/s, training_loss=0.207]
# Epoch 1:   1%|          | 281/38778 [01:44<3:57:40,  2.70it/s, training_loss=0.207]
# Epoch 1:   1%|          | 281/38778 [01:44<3:57:40,  2.70it/s, training_loss=0.203]
# Epoch 1:   1%|          | 282/38778 [01:44<3:57:40,  2.70it/s, training_loss=0.203]
# Epoch 1:   1%|          | 282/38778 [01:45<3:57:40,  2.70it/s, training_loss=0.237]
# Epoch 1:   1%|          | 283/38778 [01:45<3:57:42,  2.70it/s, training_loss=0.237]
# Epoch 1:   1%|          | 283/38778 [01:45<3:57:42,  2.70it/s, training_loss=0.399]
# Epoch 1:   1%|          | 284/38778 [01:45<3:57:57,  2.70it/s, training_loss=0.399]
# Epoch 1:   1%|          | 284/38778 [01:45<3:57:57,  2.70it/s, training_loss=0.356]
# Epoch 1:   1%|          | 285/38778 [01:45<3:57:50,  2.70it/s, training_loss=0.356]
# Epoch 1:   1%|          | 285/38778 [01:46<3:57:50,  2.70it/s, training_loss=0.258]
# Epoch 1:   1%|          | 286/38778 [01:46<3:57:38,  2.70it/s, training_loss=0.258]
# Epoch 1:   1%|          | 286/38778 [01:46<3:57:38,  2.70it/s, training_loss=0.338]
# ...
# Validating:  52%|█████▏    | 4516/8733 [06:03<05:37, 12.48it/s]
# Validating:  52%|█████▏    | 4518/8733 [06:03<05:38, 12.47it/s]
# Validating:  52%|█████▏    | 4520/8733 [06:03<05:37, 12.47it/s]
# Validating:  52%|█████▏    | 4522/8733 [06:03<05:37, 12.47it/s]
# Validating:  52%|█████▏    | 4524/8733 [06:04<05:37, 12.48it/s]
# Validating:  52%|█████▏    | 4526/8733 [06:04<05:37, 12.48it/s]
# Validating:  52%|█████▏    | 4528/8733 [06:04<05:37, 12.45it/s]
# Validating:  52%|█████▏    | 4530/8733 [06:04<05:37, 12.45it/s]
# Validating:  52%|█████▏    | 4532/8733 [06:04<05:37, 12.45it/s]
# Validating:  52%|█████▏    | 4534/8733 [06:04<05:37, 12.44it/s]
# Validating:  52%|█████▏    | 4536/8733 [06:05<05:37, 12.44it/s]
# Validating:  52%|█████▏    | 4538/8733 [06:05<05:37, 12.43it/s]
# Validating:  52%|█████▏    | 4540/8733 [06:05<05:38, 12.40it/s]
# Validating:  52%|█████▏    | 4542/8733 [06:05<05:37, 12.41it/s]
# Validating:  52%|█████▏    | 4544/8733 [06:05<05:37, 12.41it/s]
# Validating:  52%|█████▏    | 4546/8733 [06:05<05:37, 12.41it/s]
# Validating:  52%|█████▏    | 4548/8733 [06:06<05:37, 12.41it/s]
# Validating:  52%|█████▏    | 4550/8733 [06:06<05:37, 12.40it/s]
# Validating:  52%|█████▏    | 4552/8733 [06:06<05:36, 12.41it/s]
# Validating:  52%|█████▏    | 4554/8733 [06:06<05:36, 12.41it/s]
# Validating:  52%|█████▏    | 4556/8733 [06:06<05:36, 12.40it/s]
# Validating:  52%|█████▏    | 4558/8733 [06:06<05:37, 12.39it/s]
# Validating:  52%|█████▏    | 4560/8733 [06:07<05:36, 12.38it/s]
# Validating:  52%|█████▏    | 4562/8733 [06:07<05:36, 12.40it/s]
# Validating:  52%|█████▏    | 4564/8733 [06:07<05:36, 12.40it/s]
# Validating:  52%|█████▏    | 4566/8733 [06:07<05:35, 12.41it/s]
# Validating:  52%|█████▏    | 4568/8733 [06:07<05:35, 12.42it/s]
# Validating:  52%|█████▏    | 4570/8733 [06:07<05:35, 12.40it/s]
# Validating:  52%|█████▏    | 4572/8733 [06:08<05:35, 12.41it/s]
# Validating:  52%|█████▏    | 4574/8733 [06:08<05:35, 12.40it/s]
# Validating:  52%|█████▏    | 4576/8733 [06:08<05:35, 12.41it/s]
# Validating:  52%|█████▏    | 4578/8733 [06:08<05:34, 12.41it/s]
# Validating:  52%|█████▏    | 4580/8733 [06:08<05:33, 12.46it/s]
# Validating:  52%|█████▏    | 4582/8733 [06:08<05:32, 12.47it/s]
# Validating:  52%|█████▏    | 4584/8733 [06:08<05:32, 12.47it/s]
# Validating:  53%|█████▎    | 4586/8733 [06:09<05:32, 12.45it/s]
# Validating:  53%|█████▎    | 4588/8733 [06:09<05:33, 12.45it/s]
# Validating:  53%|█████▎    | 4590/8733 [06:09<05:32, 12.45it/s]
# Validating:  53%|█████▎    | 4592/8733 [06:09<05:32, 12.46it/s]
# Validating:  53%|█████▎    | 4594/8733 [06:09<05:31, 12.48it/s]
# Validating:  53%|█████▎    | 4596/8733 [06:09<05:32, 12.46it/s]
# Validating:  53%|█████▎    | 4598/8733 [06:10<05:32, 12.45it/s]
# Validating:  53%|█████▎    | 4600/8733 [06:10<05:32, 12.44it/s]
# Validating:  53%|█████▎    | 4602/8733 [06:10<05:32, 12.44it/s]
# Validating:  53%|█████▎    | 4604/8733 [06:10<05:31, 12.45it/s]
# Validating:  53%|█████▎    | 4606/8733 [06:10<05:31, 12.44it/s]
# Validating:  53%|█████▎    | 4608/8733 [06:10<05:31, 12.43it/s]
# Validating:  53%|█████▎    | 4610/8733 [06:11<05:31, 12.42it/s]
# Validating:  53%|█████▎    | 4612/8733 [06:11<05:31, 12.43it/s]
# Validating:  53%|█████▎    | 4614/8733 [06:11<05:31, 12.44it/s]
# Validating:  53%|█████▎    | 4616/8733 [06:11<05:31, 12.42it/s]
# Validating:  53%|█████▎    | 4618/8733 [06:11<05:31, 12.42it/s]
# Validating:  53%|█████▎    | 4620/8733 [06:11<05:30, 12.44it/s]
# Validating:  53%|█████▎    | 4622/8733 [06:12<05:30, 12.42it/s]
# Validating:  53%|█████▎    | 4624/8733 [06:12<05:30, 12.42it/s]
# Validating:  53%|█████▎    | 4626/8733 [06:12<05:30, 12.42it/s]
# Validating:  53%|█████▎    | 4628/8733 [06:12<05:30, 12.43it/s]
# Validating:  53%|█████▎    | 4630/8733 [06:12<05:29, 12.44it/s]
# Validating:  53%|█████▎    | 4632/8733 [06:12<05:29, 12.44it/s]
# Validating:  53%|█████▎    | 4634/8733 [06:12<05:29, 12.43it/s]
# Validating:  53%|█████▎    | 4636/8733 [06:13<05:29, 12.42it/s]
# Validating:  53%|█████▎    | 4638/8733 [06:13<05:29, 12.44it/s]
# Validating:  53%|█████▎    | 4640/8733 [06:13<05:29, 12.44it/s]
# Validating:  53%|█████▎    | 4642/8733 [06:13<05:27, 12.47it/s]
# Validating:  53%|█████▎    | 4644/8733 [06:13<05:27, 12.48it/s]
# Validating:  53%|█████▎    | 4646/8733 [06:13<05:27, 12.50it/s]
# Validating:  53%|█████▎    | 4648/8733 [06:14<05:26, 12.50it/s]
# Validating:  53%|█████▎    | 4650/8733 [06:14<05:27, 12.48it/s]
# Validating:  53%|█████▎    | 4652/8733 [06:14<05:26, 12.48it/s]
# Validating:  53%|█████▎    | 4654/8733 [06:14<05:26, 12.48it/s]
# Validating:  53%|█████▎    | 4656/8733 [06:14<05:26, 12.49it/s]
# Validating:  53%|█████▎    | 4658/8733 [06:14<05:26, 12.50it/s]
# Validating:  53%|█████▎    | 4660/8733 [06:15<05:25, 12.50it/s]
# Validating:  53%|█████▎    | 4662/8733 [06:15<05:25, 12.49it/s]
# Validating:  53%|█████▎    | 4664/8733 [06:15<05:25, 12.50it/s]
# Validating:  53%|█████▎    | 4666/8733 [06:15<05:26, 12.46it/s]
# Validating:  53%|█████▎    | 4668/8733 [06:15<05:26, 12.44it/s]
# Validating:  53%|█████▎    | 4670/8733 [06:15<05:27, 12.42it/s]
# Validating:  53%|█████▎    | 4672/8733 [06:16<05:27, 12.41it/s]
# Validating:  54%|█████▎    | 4674/8733 [06:16<05:26, 12.43it/s]
# Validating:  54%|█████▎    | 4676/8733 [06:16<05:26, 12.41it/s]
# Validating:  54%|█████▎    | 4678/8733 [06:16<05:26, 12.41it/s]
# Validating:  54%|█████▎    | 4680/8733 [06:16<05:25, 12.43it/s]
# Validating:  54%|█████▎    | 4682/8733 [06:16<05:25, 12.44it/s]
# Validating:  54%|█████▎    | 4684/8733 [06:17<05:25, 12.43it/s]
# Validating:  54%|█████▎    | 4686/8733 [06:17<05:25, 12.44it/s]
# Validating:  54%|█████▎    | 4688/8733 [06:17<05:24, 12.45it/s]
# Validating:  54%|█████▎    | 4690/8733 [06:17<05:24, 12.47it/s]
# Validating:  54%|█████▎    | 4692/8733 [06:17<05:23, 12.48it/s]
# Validating:  54%|█████▍    | 4694/8733 [06:17<05:23, 12.47it/s]
# Validating:  54%|█████▍    | 4696/8733 [06:17<05:23, 12.47it/s]
# Validating:  54%|█████▍    | 4698/8733 [06:18<05:23, 12.47it/s]
# Validating:  54%|█████▍    | 4700/8733 [06:18<05:23, 12.46it/s]
# Validating:  54%|█████▍    | 4702/8733 [06:18<05:23, 12.47it/s]
# Validating:  54%|█████▍    | 4704/8733 [06:18<05:22, 12.49it/s]
# Validating:  54%|█████▍    | 4706/8733 [06:18<05:22, 12.50it/s]
# Validating:  54%|█████▍    | 4708/8733 [06:18<05:22, 12.48it/s]
# Validating:  54%|█████▍    | 4710/8733 [06:19<05:22, 12.47it/s]
# Validating:  54%|█████▍    | 4712/8733 [06:19<05:22, 12.48it/s]
# Validating:  54%|█████▍    | 4714/8733 [06:19<05:22, 12.48it/s]
# Validating:  54%|█████▍    | 4716/8733 [06:19<05:22, 12.47it/s]
# Validating:  54%|█████▍    | 4718/8733 [06:19<05:22, 12.47it/s]
# Validating:  54%|█████▍    | 4720/8733 [06:19<05:21, 12.47it/s]
# Validating:  54%|█████▍    | 4722/8733 [06:20<05:21, 12.47it/s]
# Validating:  54%|█████▍    | 4724/8733 [06:20<05:21, 12.49it/s]
# Validating:  54%|█████▍    | 4726/8733 [06:20<05:20, 12.48it/s]
# Validating:  54%|█████▍    | 4728/8733 [06:20<05:20, 12.48it/s]
# Validating:  54%|█████▍    | 4730/8733 [06:20<05:20, 12.48it/s]
# Validating:  54%|█████▍    | 4732/8733 [06:20<05:20, 12.47it/s]
# Validating:  54%|█████▍    | 4734/8733 [06:21<05:21, 12.45it/s]
# Validating:  54%|█████▍    | 4736/8733 [06:21<05:21, 12.44it/s]
# Validating:  54%|█████▍    | 4738/8733 [06:21<05:21, 12.43it/s]
# Validating:  54%|█████▍    | 4740/8733 [06:21<05:21, 12.43it/s]
# Validating:  54%|█████▍    | 4742/8733 [06:21<05:20, 12.44it/s]
# Validating:  54%|█████▍    | 4744/8733 [06:21<05:20, 12.43it/s]
# Validating:  54%|█████▍    | 4746/8733 [06:21<05:20, 12.45it/s]
# Validating:  54%|█████▍    | 4748/8733 [06:22<05:20, 12.42it/s]
# Validating:  54%|█████▍    | 4750/8733 [06:22<05:20, 12.42it/s]
# Validating:  54%|█████▍    | 4752/8733 [06:22<05:20, 12.42it/s]
# Validating:  54%|█████▍    | 4754/8733 [06:22<05:20, 12.40it/s]
# Validating:  54%|█████▍    | 4756/8733 [06:22<05:20, 12.42it/s]
# Validating:  54%|█████▍    | 4758/8733 [06:22<05:19, 12.43it/s]
# Validating:  55%|█████▍    | 4760/8733 [06:23<05:19, 12.42it/s]
# Validating:  55%|█████▍    | 4762/8733 [06:23<05:19, 12.44it/s]
# Validating:  55%|█████▍    | 4764/8733 [06:23<05:19, 12.43it/s]
# Validating:  55%|█████▍    | 4766/8733 [06:23<05:19, 12.41it/s]
# Validating:  55%|█████▍    | 4768/8733 [06:23<05:19, 12.41it/s]
# Validating:  55%|█████▍    | 4770/8733 [06:23<05:19, 12.42it/s]
# Validating:  55%|█████▍    | 4772/8733 [06:24<05:18, 12.45it/s]
# Validating:  55%|█████▍    | 4774/8733 [06:24<05:18, 12.44it/s]
# Validating:  55%|█████▍    | 4776/8733 [06:24<05:17, 12.45it/s]
# Validating:  55%|█████▍    | 4778/8733 [06:24<05:17, 12.44it/s]
# Validating:  55%|█████▍    | 4780/8733 [06:24<05:18, 12.43it/s]
# Validating:  55%|█████▍    | 4782/8733 [06:24<05:17, 12.44it/s]
# Validating:  55%|█████▍    | 4784/8733 [06:25<05:17, 12.44it/s]
# Validating:  55%|█████▍    | 4786/8733 [06:25<05:17, 12.45it/s]
# Validating:  55%|█████▍    | 4788/8733 [06:25<05:16, 12.45it/s]
# Validating:  55%|█████▍    | 4790/8733 [06:25<05:17, 12.43it/s]
# Validating:  55%|█████▍    | 4792/8733 [06:25<05:17, 12.41it/s]
# Validating:  55%|█████▍    | 4794/8733 [06:25<05:17, 12.42it/s]
# Validating:  55%|█████▍    | 4796/8733 [06:26<05:16, 12.44it/s]
# Validating:  55%|█████▍    | 4798/8733 [06:26<05:16, 12.44it/s]
# Validating:  55%|█████▍    | 4800/8733 [06:26<05:16, 12.43it/s]
# Validating:  55%|█████▍    | 4802/8733 [06:26<05:16, 12.43it/s]
# Validating:  55%|█████▌    | 4804/8733 [06:26<05:16, 12.42it/s]
# Validating:  55%|█████▌    | 4806/8733 [06:26<05:15, 12.43it/s]
# Validating:  55%|█████▌    | 4808/8733 [06:26<05:15, 12.44it/s]
# Validating:  55%|█████▌    | 4810/8733 [06:27<05:16, 12.41it/s]
# Validating:  55%|█████▌    | 4812/8733 [06:27<05:16, 12.39it/s]
# Validating:  55%|█████▌    | 4814/8733 [06:27<05:15, 12.40it/s]
# Validating:  55%|█████▌    | 4816/8733 [06:27<05:16, 12.40it/s]
# Validating:  55%|█████▌    | 4818/8733 [06:27<05:15, 12.42it/s]
# Validating:  55%|█████▌    | 4820/8733 [06:27<05:15, 12.41it/s]
# Validating:  55%|█████▌    | 4822/8733 [06:28<05:14, 12.43it/s]
# Validating:  55%|█████▌    | 4824/8733 [06:28<05:14, 12.42it/s]
# Validating:  55%|█████▌    | 4826/8733 [06:28<05:14, 12.41it/s]
# Validating:  55%|█████▌    | 4828/8733 [06:28<05:14, 12.43it/s]
# Validating:  55%|█████▌    | 4830/8733 [06:28<05:14, 12.42it/s]
# Validating:  55%|█████▌    | 4832/8733 [06:28<05:14, 12.42it/s]
# Validating:  55%|█████▌    | 4834/8733 [06:29<05:13, 12.44it/s]
# Validating:  55%|█████▌    | 4836/8733 [06:29<05:13, 12.44it/s]
# Validating:  55%|█████▌    | 4838/8733 [06:29<05:13, 12.44it/s]
# Validating:  55%|█████▌    | 4840/8733 [06:29<05:12, 12.44it/s]
# Validating:  55%|█████▌    | 4842/8733 [06:29<05:12, 12.44it/s]
# Validating:  55%|█████▌    | 4844/8733 [06:29<05:12, 12.44it/s]
# Validating:  55%|█████▌    | 4846/8733 [06:30<05:12, 12.45it/s]
# Validating:  56%|█████▌    | 4848/8733 [06:30<05:11, 12.45it/s]
# Validating:  56%|█████▌    | 4850/8733 [06:30<05:12, 12.44it/s]
# Validating:  56%|█████▌    | 4852/8733 [06:30<05:12, 12.43it/s]
# Validating:  56%|█████▌    | 4854/8733 [06:30<05:12, 12.43it/s]
# Validating:  56%|█████▌    | 4856/8733 [06:30<05:12, 12.43it/s]
# Validating:  56%|█████▌    | 4858/8733 [06:30<05:12, 12.42it/s]
# Validating:  56%|█████▌    | 4860/8733 [06:31<05:12, 12.38it/s]
# Validating:  56%|█████▌    | 4862/8733 [06:31<05:11, 12.41it/s]
# Validating:  56%|█████▌    | 4864/8733 [06:31<05:11, 12.42it/s]
# Validating:  56%|█████▌    | 4866/8733 [06:31<05:11, 12.43it/s]
# Validating:  56%|█████▌    | 4868/8733 [06:31<05:11, 12.41it/s]
# Validating:  56%|█████▌    | 4870/8733 [06:31<05:11, 12.42it/s]
# Validating:  56%|█████▌    | 4872/8733 [06:32<05:10, 12.42it/s]
# Validating:  56%|█████▌    | 4874/8733 [06:32<05:10, 12.41it/s]
# Validating:  56%|█████▌    | 4876/8733 [06:32<05:10, 12.43it/s]
# Validating:  56%|█████▌    | 4878/8733 [06:32<05:10, 12.42it/s]
# Validating:  56%|█████▌    | 4880/8733 [06:32<05:10, 12.43it/s]
# Validating:  56%|█████▌    | 4882/8733 [06:32<05:09, 12.45it/s]
# Validating:  56%|█████▌    | 4884/8733 [06:33<05:08, 12.47it/s]
# Validating:  56%|█████▌    | 4886/8733 [06:33<05:08, 12.45it/s]
# Validating:  56%|█████▌    | 4888/8733 [06:33<05:08, 12.45it/s]
# Validating:  56%|█████▌    | 4890/8733 [06:33<05:09, 12.41it/s]
# Validating:  56%|█████▌    | 4892/8733 [06:33<05:09, 12.40it/s]
# Validating:  56%|█████▌    | 4894/8733 [06:33<05:09, 12.40it/s]
# Validating:  56%|█████▌    | 4896/8733 [06:34<05:08, 12.42it/s]
# Validating:  56%|█████▌    | 4898/8733 [06:34<05:08, 12.44it/s]
# Validating:  56%|█████▌    | 4900/8733 [06:34<05:07, 12.45it/s]
# Validating:  56%|█████▌    | 4902/8733 [06:34<05:08, 12.44it/s]
# Validating:  56%|█████▌    | 4904/8733 [06:34<05:07, 12.45it/s]
# Validating:  56%|█████▌    | 4906/8733 [06:34<05:07, 12.44it/s]
# Validating:  56%|█████▌    | 4908/8733 [06:35<05:07, 12.45it/s]
# Validating:  56%|█████▌    | 4910/8733 [06:35<05:07, 12.44it/s]
# Validating:  56%|█████▌    | 4912/8733 [06:35<05:07, 12.44it/s]
# Validating:  56%|█████▋    | 4914/8733 [06:35<05:06, 12.44it/s]
# Validating:  56%|█████▋    | 4916/8733 [06:35<05:06, 12.44it/s]
# Validating:  56%|█████▋    | 4918/8733 [06:35<05:07, 12.41it/s]
# Validating:  56%|█████▋    | 4920/8733 [06:35<05:07, 12.41it/s]
# Validating:  56%|█████▋    | 4922/8733 [06:36<05:06, 12.42it/s]
# Validating:  56%|█████▋    | 4924/8733 [06:36<05:06, 12.44it/s]
# Validating:  56%|█████▋    | 4926/8733 [06:36<05:05, 12.45it/s]
# Validating:  56%|█████▋    | 4928/8733 [06:36<05:05, 12.45it/s]
# Validating:  56%|█████▋    | 4930/8733 [06:36<05:05, 12.43it/s]
# Validating:  56%|█████▋    | 4932/8733 [06:36<05:06, 12.41it/s]
# Validating:  56%|█████▋    | 4934/8733 [06:37<05:05, 12.42it/s]
# Validating:  57%|█████▋    | 4936/8733 [06:37<05:05, 12.42it/s]
# Validating:  57%|█████▋    | 4938/8733 [06:37<05:05, 12.42it/s]
# Validating:  57%|█████▋    | 4940/8733 [06:37<05:05, 12.43it/s]
# Validating:  57%|█████▋    | 4942/8733 [06:37<05:04, 12.43it/s]
# Validating:  57%|█████▋    | 4944/8733 [06:37<05:04, 12.45it/s]
# Validating:  57%|█████▋    | 4946/8733 [06:38<05:04, 12.44it/s]
# Validating:  57%|█████▋    | 4948/8733 [06:38<05:04, 12.43it/s]
# Validating:  57%|█████▋    | 4950/8733 [06:38<05:04, 12.43it/s]
# Validating:  57%|█████▋    | 4952/8733 [06:38<05:04, 12.42it/s]
# Validating:  57%|█████▋    | 4954/8733 [06:38<05:04, 12.41it/s]
# Validating:  57%|█████▋    | 4956/8733 [06:38<05:03, 12.44it/s]
# Validating:  57%|█████▋    | 4958/8733 [06:39<05:03, 12.46it/s]
# Validating:  57%|█████▋    | 4960/8733 [06:39<05:02, 12.48it/s]
# Validating:  57%|█████▋    | 4962/8733 [06:39<05:02, 12.47it/s]
# Validating:  57%|█████▋    | 4964/8733 [06:39<05:02, 12.46it/s]
# Validating:  57%|█████▋    | 4966/8733 [06:39<05:02, 12.46it/s]
# Validating:  57%|█████▋    | 4968/8733 [06:39<05:02, 12.45it/s]
# Validating:  57%|█████▋    | 4970/8733 [06:40<05:02, 12.42it/s]
# Validating:  57%|█████▋    | 4972/8733 [06:40<05:01, 12.46it/s]
# Validating:  57%|█████▋    | 4974/8733 [06:40<05:01, 12.46it/s]
# Validating:  57%|█████▋    | 4976/8733 [06:40<05:01, 12.46it/s]
# Validating:  57%|█████▋    | 4978/8733 [06:40<05:01, 12.46it/s]
# Validating:  57%|█████▋    | 4980/8733 [06:40<05:00, 12.47it/s]
# Validating:  57%|█████▋    | 4982/8733 [06:40<05:01, 12.45it/s]
# Validating:  57%|█████▋    | 4984/8733 [06:41<05:01, 12.43it/s]
# Validating:  57%|█████▋    | 4986/8733 [06:41<05:01, 12.43it/s]
# Validating:  57%|█████▋    | 4988/8733 [06:41<05:01, 12.42it/s]
# Validating:  57%|█████▋    | 4990/8733 [06:41<05:01, 12.41it/s]
# Validating:  57%|█████▋    | 4992/8733 [06:41<05:01, 12.40it/s]
# Validating:  57%|█████▋    | 4994/8733 [06:41<05:01, 12.42it/s]
# Validating:  57%|█████▋    | 4996/8733 [06:42<05:00, 12.44it/s]
# Validating:  57%|█████▋    | 4998/8733 [06:42<05:00, 12.43it/s]
# Validating:  57%|█████▋    | 5000/8733 [06:42<04:59, 12.45it/s]
# Validating:  57%|█████▋    | 5002/8733 [06:42<04:59, 12.45it/s]
# Validating:  57%|█████▋    | 5004/8733 [06:42<04:59, 12.46it/s]
# Validating:  57%|█████▋    | 5006/8733 [06:42<04:59, 12.45it/s]
# Validating:  57%|█████▋    | 5008/8733 [06:43<04:59, 12.46it/s]
# Validating:  57%|█████▋    | 5010/8733 [06:43<04:58, 12.46it/s]
# Validating:  57%|█████▋    | 5012/8733 [06:43<04:58, 12.46it/s]
# Validating:  57%|█████▋    | 5014/8733 [06:43<04:58, 12.46it/s]

# %% [markdown]
# # Evaluate

# %%
from tqdm.notebook import tqdm

model.load_state_dict(torch.load('./modelsUNK-pnn/finetuned_BERT_epoch_1.model', map_location=torch.device('cpu')))

_, predictions, true_vals = evaluate(dataloader_validation)
preds_flat = np.argmax(predictions, axis=1).flatten()
# Out:
# Validating:   0%|          | 0/8733 [00:00<?, ?it/s]

# %%
val_f1 = f1_score_func(predictions, true_vals)

print('F1:')
print(val_f1)

# %%
print(classification_report(true_vals, preds_flat))

# %%
pd.DataFrame(confusion_matrix(true_vals, preds_flat),
        index = [['actual', 'actual', 'actual'], ['neutral', 'positive', 'negative']],
        columns = [['predicted', 'predicted', 'predicted'], ['neutral', 'positive', 'negative']]
